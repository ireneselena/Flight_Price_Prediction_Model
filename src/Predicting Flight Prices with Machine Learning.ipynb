# %% [markdown]
# <h1 style='text-align:center; color:darkcyan'><b> Predicting Flight Prices with Machine Learning </b></h1>
# <h5 style="text-align: center;">Irene Selena Mulyono JCDS 0410 - 005</h2>

# %% [markdown]
# <h2 style='text-align:left; color:darkblue'><b> Business Understanding </b></h1>
#
# <h4 style='text-align:left; color:darkcyan'><b> Context </b></h4>
#
# The travel industry is rapidly evolving, driven by technological advancements and shifting consumer behaviors. It serves a diverse group of users, including frequent travelers, business professionals, and budget-conscious backpackers, each with unique needs. Air travel, while convenient and fast, often represents a significant portion of overall travel expenses, making proper budgeting essential.
#
# Understanding and predicting flight prices is crucial for effective travel planning. Anticipating fluctuations in airfare can help travelers manage their budgets more effectively, ensuring their trips are both affordable and well-planned. This knowledge is not only valuable for individual travelers but also for businesses and travel agencies looking to optimize their travel-related expenses.
#
# <h4 style='text-align:left; color:darkcyan'><b> Problem Statement </b></h4>
#
# 1. Who are the users facing the problem?
#
#     All types of travelers : leisure travelers, business travelers, and backpackers
#
#
# 2. What problem do these users face?
#
#     Users need to plan and allocate a proper budget for their travel needs, specifically for airfare, which can be challenging due to fluctuating prices. According to this [Travel Blog](https://www.seekingneverland.com/how-much-should-i-budget-for-vacation/), Flight tickets usually takes up to 20% of our travel budget, which can be considered as a significat amount to prepare for.
#
#
# 3. Why does this problem needs to be solved?
#
#     Solving this problems will help the users with:
#     - **Effective Budgeting**: helps users plan and allocate their travel budgets more effectively, ensuring they are financially prepared for their trips.
#
#     - **Cost Savings**: By predicting flight prices, users can save money by avoiding overpriced flights, enabling them to make more cost-effective travel decisions.
#
#     - **Risk Mitigation**: Addressing this issue minimizes the risk of budget shortfalls or unexpected financial strain due to fluctuating airfare costs.
#
# <h4 style='text-align:left; color:darkcyan'><b> Goals </b></h4>
#
# Our goal for this project is to provide travelers with the tools they need to budget effectively for their trips by understanding and predicting flight prices. By identifying patterns in airfare and forecasting future prices, we aim to help travelers make more informed decisions, thereby reducing the financial uncertainty associated with air travel. The specific goals of this project are:
#
# 1. **Explore FLight Price Patterns**:
#
#     Analyze the dataset to uncover and understand the factors that influence flight prices, such as the airline, source and destination cities, departure and arrival times, stops, and travel class. This analysis will highlight key trends and patterns that affect pricing.
#
# 2. **Predict Future Flight Prices**:
#
#     Develop a supervised regression model to predict future flight prices based on the identified features. This model will enable travelers to anticipate airfare changes and plan their travel budgets accordingly.
#
# The ultimate objective is to create a reliable predictive tool that empowers travelers to optimize their travel expenses by making informed decisions about when to book flights, ensuring a better allocation of their travel budget.
#
# <h4 style='text-align:left; color:darkcyan'><b> Analytical Approach </b></h4>
#
# 1. **Proposed Solution**:
#
#     - To address the problem at hand, we will employ a predictive analytics approach aimed at forecasting flight prices. The goal is to provide travelers with accurate predictions of airfare based on various factors, helping them budget more effectively for their travel plans.
#
#     - Given that we have a labeled dataset with a clear target variable (flight price), this project will utilize a supervised regression model. By training the model on historical flight data, it will learn to identify patterns and trends that influence airfare, enabling accurate price predictions.
#
# 2. **Implementation and Usage**:
#
#     This solution can be implemented every time a user is planning their travel budget. By using the trained model, travelers can predict future flight prices and determine the optimal time to purchase tickets. This allows them to plan their travel expenses more efficiently, avoid overpaying for flights, and allocate their budget more effectively across their entire trip.
#
# <h4 style='text-align:left; color:darkcyan'><b> Success Criteria </b></h4>
#
# 1. Miss Prediction
#     - **Overprediction: Overestimating Flight Costs**
#         - **Excessive Budget Allocation**:
#             Overestimating flight prices may lead travelers to allocate more of their travel budget to airfare than necessary. This could result in unnecessarily cutting back on other aspects of their trip, such as accommodation, dining, or activities, reducing the overall quality of their travel experience.
#         - **Missed Travel Opportunities**:
#             Travelers might avoid booking flights altogether if the predicted prices are too high, causing them to miss out on travel opportunities or postpone trips that could have been more affordable than anticipated.
#
#     - **Underprediction: Insufficient Budget Planning**
#         - **Budget Shortfalls**:
#             Underestimating flight prices may cause travelers to allocate too little money for airfare, leading to budget shortfalls when they need to purchase tickets. This can force them to dip into other parts of their budget, potentially disrupting their entire travel plan.
#         - **Last-Minute Financial Strains**:
#             If actual prices exceed predictions, travelers might face last-minute financial strain, needing to pay more than expected. This could lead to stress, hasty decisions, or even canceling travel plans due to insufficient funds.
#
# 2. Assumptions
#
#     - **Consistency of Flight Price Patterns Over Time**:
#
#         It is assumed that the patterns in flight prices observed during the data collection period from February 11th to March 31st, 2022, will continue to hold in future predictions. However, if there are significant changes in airline pricing strategies, demand fluctuations, or external factors such as economic conditions or regulatory changes, the predictive accuracy of the model may be affected.
#
#     - **Accuracy and Representativeness of Collected Data**:
#
#         It is assumed that the data collected using the Octoparse scraping tool is accurate and representative of the general flight pricing trends during the collection period. Any inaccuracies in the data, such as missing or erroneous records, could impact the model's ability to make reliable predictions.
#
#     - **Segmentation of Data by Ticket Class**:
#
#         The data was segmented into economy and business class tickets, and it is assumed that these two classes represent distinct segments with different pricing dynamics. The model’s predictions are based on this segmentation, and any blending or crossover in pricing trends between these segments could reduce the precision of the predictions.
#
# <h4 style='text-align:left; color:darkcyan'><b> Project Limitation </b></h4>
#
# - **Data Limitation:** The accuracy of flight price predictions is highly dependent on the quality and completeness of the historical data collected. Incomplete or biased data may reduce the effectiveness of the predictive model, potentially leading to inaccurate forecasts.
#
# - **Model Interpretation:** The complexity of the predictive regression model may pose challenges for non-technical stakeholders in interpreting the results. This could affect the adoption and application of the model's outcomes in travel planning and budgeting decisions.
#
# - **Market Dynamics:** External changes not captured in the historical data, such as shifts in airline pricing strategies, economic conditions, or travel regulations, may impact the accuracy of the flight price predictions and their relevance for future travel plans.

# %% [markdown]
# <h2 style='text-align:left; color:darkblue'><b> Data Understanding </b></h1>
#
# <h4 style='text-align:left; color:darkcyan'><b> Data Source </b></h4>
#
# The dataset used in this project was collected from [Kaggle](https://www.kaggle.com/datasets/shubhambathwal/flight-price-prediction), this data was collected using the Octoparse scraping tool from the Ease My Trip website. The data comprises 300,261 distinct flight booking options, segmented into economy and business class tickets. The collection period spanned 50 days, from February 11th to March 31st, 2022. The dataset is secondary in nature and does not include specific information about its original creators or collectors, nor does it specify the exact time of its creation.
#
# <h4 style='text-align:left; color:darkcyan'><b> Data Understanding & Implication Towards Business Context: </b></h4>
#
# | **Column Name**      | **Description**                                                | **Implication to Context**                                                                                 |
# |----------------------|----------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------|
# | **Airline**          | The name of the airline company.                               | Different airlines may have varying pricing strategies, which can significantly impact the ticket prices.    |
# | **Flight**           | Stores information regarding the plane's flight code.          | The flight code could be associated with specific routes, times, or classes that affect the overall pricing.  |
# | **Source City**      | City from which the flight takes off.                          | The departure city can influence demand and pricing, with some cities having higher or lower flight costs.    |
# | **Departure Time**   | Categorical feature grouping time periods into bins.           | Flights departing at certain times of day might be more expensive due to peak travel times and higher demand. |
# | **Stops**            | Number of stops between the source and destination cities.     | The number of stops typically impacts ticket prices, with non-stop flights often being more expensive.        |
# | **Arrival Time**     | Categorical feature grouping time intervals into bins.         | Arrival times can affect ticket prices, especially for flights arriving during peak or off-peak hours.        |
# | **Destination City** | City where the flight will land.                               | Destination cities have varying levels of demand, which can influence the cost of tickets.                    |
# | **Class**            | Information on seat class (Business or Economy).               | Business class tickets are generally more expensive than economy, reflecting the added comfort and amenities. |
# | **Duration**         | Overall time taken to travel between cities in hours.          | Longer durations, particularly with layovers, might result in cheaper tickets but longer travel times.        |
# | **Days Left**        | Calculated by subtracting the trip date from the booking date. | The number of days left before departure can heavily influence pricing, with last-minute bookings often costing more. |
# | **Price**            | Target variable storing information on the ticket price.       | The key variable of interest for predicting and analyzing how the above factors influence the cost of flights.|
#
#
# <h4 style='text-align:left; color:darkcyan'><b> Data Representativeness </b></h4>
#
# Based on the data and available features, it can be concluded that the current dataset is sufficient to build a predictive model for flight price predictions.

# %% [markdown]
# <h4 style='text-align:left; color:darkcyan'><b> Import Libraries </b></h4>

# %%
# Library for Saving Model
import os
import pickle

# Library for Data Wrangling
import pandas as pd 
import numpy as np

# Library for Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Library for Statistics
import scipy.stats as stats
from scipy.stats import shapiro
from scipy.stats import f_oneway

# PyCaret regression module
from pycaret.regression import *

# Library for Preprocessing
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from category_encoders import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder, RobustScaler
from sklearn.compose import ColumnTransformer, TransformedTargetRegressor
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.base import BaseEstimator, TransformerMixin
from xgboost import XGBRegressor

# Library for ML Algorithm
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor, ExtraTreesRegressor

# Library for Evaluation
from sklearn.model_selection import cross_validate, LearningCurveDisplay
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_error, make_scorer
from SegmentPerformance import *

# Library for Warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h4 style='text-align:left; color:darkcyan'><b> Load Dataset </b></h4>

# %%
df = pd.read_csv('Flight_Price.csv')
# Drop Redundant Column
df = df.drop(columns='Unnamed: 0')

# %%
df.head(10)
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
# 5   Vistara   UK-945       Delhi        Morning  zero      Afternoon
# 6   Vistara   UK-927       Delhi        Morning  zero        Morning
# 7   Vistara   UK-951       Delhi      Afternoon  zero        Evening
# 8  GO_FIRST   G8-334       Delhi  Early_Morning  zero        Morning
# 9  GO_FIRST   G8-336       Delhi      Afternoon  zero        Evening
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# ...

# %%
# Fore Ease of Understanding, We Decided to Convert the `price` values from Rupees to USD with a Conversion Rate of 1 Rupee = 0.012 USD

df['price'] = round(df['price']*0.012,2)

# %%
df.head(10)
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
# 5   Vistara   UK-945       Delhi        Morning  zero      Afternoon
# 6   Vistara   UK-927       Delhi        Morning  zero        Morning
# 7   Vistara   UK-951       Delhi      Afternoon  zero        Evening
# 8  GO_FIRST   G8-334       Delhi  Early_Morning  zero        Morning
# 9  GO_FIRST   G8-336       Delhi      Afternoon  zero        Evening
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1  71.44
# 1           Mumbai  Economy      2.33          1  71.44
# ...

# %% [markdown]
# <h4 style='text-align:left; color:darkcyan'><b> Data Size: Amount and Range </b></h4>

# %%
print(f'Amount of rows and columns in dataset: {df.shape}')
# Out:
# Amount of rows and columns in dataset: (300153, 11)

# %%
# An initial check of what is in our data
pd.DataFrame({
    'column': df.columns.values,
    'type': df.dtypes.values,
    'count': [df[col].shape[0] for col in df.columns],
    'N/A (%)': df.isna().mean() * 100,
    'n_unique': df.nunique().values,
    'sample_unique': [df[col].unique() for col in df.columns]
})
# Out:
#                             column     type   count  N/A (%)  n_unique  \
# airline                    airline   object  300153      0.0         6
# flight                      flight   object  300153      0.0      1561
# source_city            source_city   object  300153      0.0         6
# departure_time      departure_time   object  300153      0.0         6
# stops                        stops   object  300153      0.0         3
# arrival_time          arrival_time   object  300153      0.0         6
# destination_city  destination_city   object  300153      0.0         6
# class                        class   object  300153      0.0         2
# duration                  duration  float64  300153      0.0       476
# days_left                days_left    int64  300153      0.0        49
# price                        price  float64  300153      0.0     12157
#
#                                                       sample_unique
# ...

# %%
# indepth information for numerical columns
df.describe()
# Out:
#             duration      days_left          price
# count  300153.000000  300153.000000  300153.000000
# mean       12.221021      26.004751     250.676072
# std         7.191997      13.561004     272.373277
# min         0.830000       1.000000      13.260000
# 25%         6.830000      15.000000      57.400000
# 50%        11.250000      26.000000      89.100000
# 75%        16.170000      38.000000     510.250000
# max        49.830000      49.000000    1476.850000

# %% [markdown]
# #### Insights from Numerical Columns
#
# 1. **duration**:
#     - The mean duration of the flights in the dataset is approximately 12.22 hours, indicating that on average, the flights have a moderate duration.
#     - The minimum flight duration is 0.83 hours, while the maximum is 49.83 hours, showing a wide range of flight lengths, possibly reflecting a mix of short domestic flights and longer international ones.
#     - The 25th percentile of duration is 6.83 hours, and the 75th percentile is 16.17 hours, meaning that 50% of the flights have durations between these two values. This indicates a concentration of flights within a moderate duration range.
#
# 2. **days_left**:
#     - The mean number of days left before departure when the ticket was booked is 26 days. This suggests that, on average, travelers book their flights nearly a month in advance.
#     - The minimum days left is just 1 day, indicating last-minute bookings, while the maximum is 49 days, reflecting early planning.
#     - With a standard deviation of 13.56 days, there is a significant variation in how far in advance flights are booked. The 25th percentile is 15 days and the 75th percentile is 38 days, showing that most bookings are made within this window.
#
# 3. **price**:
#     - The mean ticket price is 250.68 dollars, with prices ranging from a minimum of 13.26 to a maximum of 1476.85 dollars. This wide range indicates significant variability in pricing, likely due to differences in routes, class, and booking times.
#     - The 25th percentile price is 57.4 dollars, and the 75th percentile is 510.25 dollars, showing that 50% of the ticket prices fall within this range, highlighting a concentration of prices within a moderate to high range.
#     - The standard deviation of 272.37 dollars is quite high, indicating considerable variability in ticket prices, which could be influenced by various factors such as airline, booking time, and class.

# %% [markdown]
# <h4 style='text-align:left; color:darkcyan'><b> Data Condition: Quality </b></h4>

# %% [markdown]
# #### Checking Data Types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           300153 non-null  object
#  1   flight            300153 non-null  object
#  2   source_city       300153 non-null  object
#  3   departure_time    300153 non-null  object
#  4   stops             300153 non-null  object
#  5   arrival_time      300153 non-null  object
#  6   destination_city  300153 non-null  object
#  7   class             300153 non-null  object
#  8   duration          300153 non-null  float64
#  9   days_left         300153 non-null  int64
#  10  price             300153 non-null  float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 25.2+ MB

# %% [markdown]
# We found no abnormal data types in our data.

# %% [markdown]
# #### Checking for Missing Values

# %%
# Checking for missing values
listItem = []
for col in df.columns :
    listItem.append([col, df[col].dtype, df[col].isna().sum(), round((df[col].isna().sum()/len(df[col])) * 100,2)]);

nulldata = pd.DataFrame(columns=['dataFeatures', 'dataType', 'null', 'nullPct'],
                     data=listItem)
nulldata
# Out:
#         dataFeatures dataType  null  nullPct
# 0            airline   object     0      0.0
# 1             flight   object     0      0.0
# 2        source_city   object     0      0.0
# 3     departure_time   object     0      0.0
# 4              stops   object     0      0.0
# 5       arrival_time   object     0      0.0
# 6   destination_city   object     0      0.0
# 7              class   object     0      0.0
# 8           duration  float64     0      0.0
# 9          days_left    int64     0      0.0
# 10             price  float64     0      0.0

# %% [markdown]
# The output above confirms that there are **no missing values** across all the features in the dataset. The `nullPct` for each feature is 0.0%, indicating a complete dataset. Since there are no missing values in the dataset, we can proceed directly to further analysis.

# %% [markdown]
# #### Checking for Duplicated Values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# We found that in this dataset, there is no duplicated values.

# %% [markdown]
# #### Checking for Outliers in Numerical Columns

# %% [markdown]
# In this dataset we have three numerical columns, namely: `duration`, `days_left`, `price`. We are going to check for any outliers and abnormalities within the value of those columns.

# %%
# Create dataframe for numerical coloms
numeric_col = df.select_dtypes(include=['number'])

# %%
# Create an empty list to store data
outliers_info = []

for col in numeric_col.columns:
    # Calculate Q1, Q3, and IQR
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    # Calculate upper and lower limits
    lower_bound = max(Q1 - 1.5 * IQR, 0)  # Set lower_bound to 0 if it's less than 0
    upper_bound = Q3 + 1.5 * IQR
    
    # Identify outliers
    outliers_condition = (df[col] < lower_bound) | (df[col] > upper_bound)
    outliers = df[outliers_condition]

    # Add iteration results to outliers_info
    outliers_info.append([col, round(lower_bound, 2), round(upper_bound, 2), outliers_condition.sum()])

# Turn outliers_info into a dataframe
df_outliers = pd.DataFrame(outliers_info, columns=['Columns', 'Lower Bound', 'Upper Bound', 'Numbers of Outliers']).set_index('Columns').reset_index()
df_outliers
# Out:
#      Columns  Lower Bound  Upper Bound  Numbers of Outliers
# 0   duration            0        30.18                 2110
# 1  days_left            0        72.50                    0
# 2      price            0      1189.53                  123

# %% [markdown]
# **Outliers**
# 1) `duration`
#
#     - **Upper Bound**: The calculated upper bound for flight duration is 30.18 hours.
#     - **Number of Outliers**: There are 2,110 outliers in the duration column.
#     - **Interpretation**: The significant number of outliers in flight duration suggests that there are numerous flights with exceptionally long travel times compared to the majority. These may include flights with multiple layovers or less direct routes. These outliers could potentially skew the model if not handled appropriately, as they represent unusual cases.
#
# 2) `days_left`
#
#     - **Upper Bound**: The calculated upper bound for days_left is 72.50 days.
#     - **Number of Outliers**: Interestingly, there are no outliers in the days_left column.
#     - **Interpretation**: The lack of outliers in the days_left column indicates that the distribution of booking times relative to the flight date is consistent across the dataset. This suggests that travelers generally book flights within a predictable range of days before departure.
#
# 3) `price`
#
#     - **Upper Bound**: The calculated upper bound for price is 1189.53 dollars.
#     - **Number of Outliers**: There are 123 outliers in the price column.
#     - **Interpretation**: The presence of 123 outliers in the price column indicates that some flight tickets are significantly more expensive than the majority. These outliers could represent premium routes, business class tickets, or last-minute bookings. It is crucial to analyze these outliers further to determine if they should be included or excluded from the model, as they might impact the model's ability to generalize.

# %% [markdown]
# #### Checking Categorical Columns

# %% [markdown]
# For categorical columns we have 8 columns, namely: `airline`, `flight`, `source_city`, `departure_time`, `stops`, `arrival_time`, `destination_city`, `class`. We are going to check for the value counts of each categorical columns.

# %% [markdown]
# `airline`

# %%
# Calculate the value counts and percentage for the housing column
airline_counts = df['airline'].value_counts()
airline_percentage = round(df['airline'].value_counts(normalize=True) * 100,2)

# Combine both into a DataFrame
airline_df = pd.DataFrame({'Count': airline_counts, 'Percentage': airline_percentage})

# Display the DataFrame
airline_df
# Out:
#             Count  Percentage
# Vistara    127859       42.60
# Air_India   80892       26.95
# Indigo      43120       14.37
# GO_FIRST    23173        7.72
# AirAsia     16098        5.36
# SpiceJet     9011        3.00

# %% [markdown]
# The majority of flights in the dataset are operated by **Vistara**, accounting for **42.6%** of the total flights, followed by **Air India** with **26.95%**. These two airlines together make up nearly 70% of the dataset, indicating their dominance in the market within this data. In contrast, **SpiceJet** has the lowest representation, with only **3.00%** of the flights. This distribution suggests that Vistara and Air India play a significant role in the dataset, and their pricing strategies may heavily influence the overall analysis of flight prices.

# %% [markdown]
# `flight`

# %%
# Calculate the value counts and percentage for the housing column
flight_counts = df['flight'].value_counts()
flight_percentage = round(df['flight'].value_counts(normalize=True) * 100,2)

# Combine both into a DataFrame
flight_df = pd.DataFrame({'Count': flight_counts, 'Percentage': flight_percentage})

# Display the DataFrame
flight_df
# Out:
#          Count  Percentage
# UK-706    3235        1.08
# UK-772    2741        0.91
# UK-720    2650        0.88
# UK-836    2542        0.85
# UK-822    2468        0.82
# ...        ...         ...
# SG-9923      1        0.00
# 6E-6474      1        0.00
# 6E-865       1        0.00
# G8-705       1        0.00
# G8-107       1        0.00
#
# [1561 rows x 2 columns]

# %% [markdown]
# The flight data is highly diverse, with **1561 unique flight codes** represented in the dataset. The most frequent flight, **UK-706**, constitutes only **1.08%** of the total flights, indicating no single flight code dominates the dataset. This distribution suggests a wide variety of routes and schedules, with most individual flights making up less than 1% of the data. The presence of numerous flight codes with very low percentages (close to 0%) reflects the broad and varied nature of the flights included in this analysis.

# %% [markdown]
# `source_city`

# %%
# Calculate the value counts and percentage for the housing column
source_city_counts = df['source_city'].value_counts()
source_city_percentage = round(df['source_city'].value_counts(normalize=True) * 100,2)

# Combine both into a DataFrame
source_city_df = pd.DataFrame({'Count': source_city_counts, 'Percentage': source_city_percentage})

# Display the DataFrame
source_city_df
# Out:
#            Count  Percentage
# Delhi      61343       20.44
# Mumbai     60896       20.29
# Bangalore  52061       17.34
# Kolkata    46347       15.44
# Hyderabad  40806       13.60
# Chennai    38700       12.89

# %% [markdown]
# The dataset shows that flights are fairly evenly distributed across several major cities, with **Delhi** (20.44%) and **Mumbai** (20.29%) being the top source cities. Together, these two cities account for over 40% of the total flights. **Bangalore** (17.34%) and **Kolkata** (15.44%) also contribute significantly, while **Hyderabad** (13.60%) and **Chennai** (12.89%) have slightly lower but still substantial representation. This distribution suggests a focus on major metropolitan areas, which are likely key hubs in the flight network represented in this dataset.

# %% [markdown]
# `departure_time`

# %%
# Calculate the value counts and percentage for the housing column
departure_time_counts = df['departure_time'].value_counts()
departure_time_percentage = round(df['departure_time'].value_counts(normalize=True) * 100,2)

# Combine both into a DataFrame
departure_time_df = pd.DataFrame({'Count': departure_time_counts, 'Percentage': departure_time_percentage})

# Display the DataFrame
departure_time_df
# Out:
#                Count  Percentage
# Morning        71146       23.70
# Early_Morning  66790       22.25
# Evening        65102       21.69
# Night          48015       16.00
# Afternoon      47794       15.92
# Late_Night      1306        0.44

# %% [markdown]
# The dataset reveals that the majority of flights depart in the **Morning** (23.70%) and **Early Morning** (22.25%), with these time slots collectively accounting for nearly half of all flights. **Evening** departures are also common, making up **21.69%** of the flights. In contrast, **Late Night** flights are the least frequent, representing only **0.44**% of the dataset. This distribution suggests a strong preference for flights during daylight and early evening hours, possibly due to convenience and demand patterns.

# %% [markdown]
# `stops`

# %%
# Calculate the value counts and percentage for the housing column
stops_counts = df['stops'].value_counts()
stops_percentage = round(df['stops'].value_counts(normalize=True) * 100,2)

# Combine both into a DataFrame
stops_df = pd.DataFrame({'Count': stops_counts, 'Percentage': stops_percentage})

# Display the DataFrame
stops_df
# Out:
#               Count  Percentage
# one          250863       83.58
# zero          36004       12.00
# two_or_more   13286        4.43

# %% [markdown]
# The majority of flights in the dataset have **one stop**, accounting for **83.58%** of the total flights. **Non-stop** flights (zero stops) make up **12.00%** of the dataset, while flights with **two or more** stops constitute the smallest group at **4.43%**. This distribution suggests that most travelers in the dataset are opting for flights with at least one stop, possibly due to cost considerations or limited availability of direct flights on certain routes.

# %% [markdown]
# `arrival_time`

# %%
# Calculate the value counts and percentage for the housing column
arrival_time_counts = df['arrival_time'].value_counts()
arrival_time_percentage = round(df['arrival_time'].value_counts(normalize=True) * 100,2)

# Combine both into a DataFrame
arrival_time_df = pd.DataFrame({'Count': arrival_time_counts, 'Percentage': arrival_time_percentage})

# Display the DataFrame
arrival_time_df
# Out:
#                Count  Percentage
# Night          91538       30.50
# Evening        78323       26.09
# Morning        62735       20.90
# Afternoon      38139       12.71
# Early_Morning  15417        5.14
# Late_Night     14001        4.66

# %% [markdown]
# The dataset indicates that the majority of flights arrive at **Night** (30.50%) and **Evening** (26.09%), with these time slots accounting for over half of all flight arrivals. **Morning** arrivals are also common, making up **20.90%** of the total. In contrast, **Early Morning** (5.14%) and **Late Nigh**t (4.66%) arrivals are the least frequent. This distribution suggests that flights are more likely to be scheduled to arrive during the night and evening hours, possibly due to scheduling efficiencies or passenger preferences.

# %% [markdown]
# `destination_city`

# %%
# Calculate the value counts and percentage for the housing column
destination_city_counts = df['destination_city'].value_counts()
destination_city_percentage = round(df['destination_city'].value_counts(normalize=True) * 100,2)

# Combine both into a DataFrame
destination_city_df = pd.DataFrame({'Count': destination_city_counts, 'Percentage': destination_city_percentage})

# Display the DataFrame
destination_city_df
# Out:
#            Count  Percentage
# Mumbai     59097       19.69
# Delhi      57360       19.11
# Bangalore  51068       17.01
# Kolkata    49534       16.50
# Hyderabad  42726       14.23
# Chennai    40368       13.45

# %% [markdown]
# The dataset indicates that flights are relatively evenly distributed among six major destination cities, with **Mumbai** (19.69%) and **Delhi** (19.11%) being the most common destinations. Together, they account for nearly 40% of the total flights. **Bangalore** (17.01%) and **Kolkata** (16.50%) also have substantial representation, while **Hyderabad** (14.23%) and **Chennai** (13.45%) are slightly less frequent. This distribution highlights these cities as key hubs in the flight network, with Mumbai and Delhi being the most prominent destinations in the dataset.

# %% [markdown]
# `class`

# %%
# Calculate the value counts and percentage for the housing column
class_counts = df['class'].value_counts()
class_percentage = round(df['class'].value_counts(normalize=True) * 100,2)

# Combine both into a DataFrame
class_df = pd.DataFrame({'Count': class_counts, 'Percentage': class_percentage})

# Display the DataFrame
class_df
# Out:
#            Count  Percentage
# Economy   206666       68.85
# Business   93487       31.15

# %% [markdown]
# The dataset shows that **Economy** class tickets are significantly more common, making up **68.85%** of the total flights, while **Business** class tickets account for **31.15%**. This indicates a strong preference for Economy class among travelers, which is likely due to cost considerations. The presence of a substantial proportion of Business class tickets also suggests a notable segment of higher-paying customers who prioritize comfort and service.

# %% [markdown]
# <h4 style='text-align:left; color:darkcyan'><b> Data Distribution & Normality Test </b></h4>

# %% [markdown]
# #### Target Distribution

# %%
# Set font to a default one
plt.rcParams['font.family'] = 'serif'

# Arrange many axes in one figure for distribution of CLV
fig, axes = plt.subplots(ncols=2, nrows=1, figsize=(16,6))


# Create a graph for each axes
sns.histplot(data=df, x='price', ax=axes[0])
sns.boxplot(data=df, x='price', ax=axes[1])

# Add a title for the entire figure
fig.suptitle('Distribution of Flight Prices', fontsize=16)

# Show graph
plt.show()

# %% [markdown]
# The distribution of flight prices is **heavily skewed to the right**, with most flights priced below $200. There are some high-price outliers extending beyond $1000, indicating a few premium-priced flights, likely due to factors such as business class or last-minute bookings.

# %% [markdown]
# #### Numerical Distribution

# %%
# Create Plot for Distribution Numerical Feature
plt.figure(figsize=(12,8))
num_subplot = 1

for i in numeric_col.drop(columns='price').columns:
    plt.subplot(2,2,num_subplot)
    sns.boxplot(data=numeric_col, x=i)
    plt.title(i, size=16)
    plt.tight_layout()
    num_subplot+=1

# %% [markdown]
# - **Duration**: The flight duration shows a spread mostly between 5 to 20 hours, with several outliers extending beyond 30 hours, indicating unusually long flights, possibly due to multiple layovers.
#
# - **Days Left**: The number of days left until departure is well-distributed between 10 and 40 days, with no significant outliers, suggesting consistent booking patterns across the dataset.

# %% [markdown]
# #### Categorical Distribution

# %%
# Create variable for feature categorical
categorical_col = df.select_dtypes(include=['object'])

# %%
# Create Plot for Distribution Categorical Feature
plt.figure(figsize=(16,12))
num_subplot = 1

for i in categorical_col:
    plt.subplot(4,2,num_subplot)
    sns.countplot(data=categorical_col, y=i, order=categorical_col[i].value_counts().index, palette='tab10')
    plt.title(i, size=16)
    plt.tight_layout()
    num_subplot+=1

# %% [markdown]
# The dataset reveals a strong presence of **Vistara** and **Air India** as the leading airlines. **Delhi** and **Mumbai** are the top source and destination cities. Most flights have **one stop**, and **Economy class** dominates over Business class. Departure times are most frequent in the **Morning**, while arrivals peak at **Night**. This distribution highlights key patterns that will influence the analysis of flight prices.

# %% [markdown]
# #### Normality Test

# %%
# Create an empty list to store data
distribution = []

# Looping for each column in numeric_col
for col in numeric_col.columns:
    # Perform normality test with Shapiro-Wilk
    stat, p_value = shapiro(df[col])
    
    # Round the p-value to 3 decimal places
    p_value = round(p_value, 3)
    
    # Determine distribution based on p-value
    dist = "Normally Distributed" if p_value > 0.05 else "Not Normally Distributed"
    
    # Save the results to a list
    distribution.append([col, stat, p_value, dist])

# Create a DataFrame from a list
df_distribution = pd.DataFrame(distribution, columns=['Column', 'Statistic', 'P-Value', 'Distribution'])
df_distribution
# Out:
#       Column  Statistic  P-Value              Distribution
# 0   duration   0.956969      0.0  Not Normally Distributed
# 1  days_left   0.959006      0.0  Not Normally Distributed
# 2      price   0.752188      0.0  Not Normally Distributed

# %% [markdown]
# Based on this result, we can see that none of the numerical columns are normally distributed.

# %% [markdown]
# <h2 style='text-align:left; color:darkblue'><b> Exploratory Data Analysis </b></h1>

# %% [markdown]
# <h4 style='text-align:left; color:darkcyan'><b> Correlation of Numerical Columns with Target </b></h4>

# %%
plt.figure(figsize=(16,8))
num_subplot = 1

for i in numeric_col.drop(columns='price'):
    plt.subplot(2,2,num_subplot)
    sns.scatterplot(data=numeric_col, x=i, y='price')
    plt.title(i, size=16)
    plt.tight_layout()
    num_subplot+=1

# %% [markdown]
# **Duration vs. Price**:
# The scatter plot shows a positive relationship between flight duration and price, with prices generally increasing as duration increases. However, this relationship appears to be spread out, with significant variation in prices for flights of similar durations. This suggests that while longer flights tend to be more expensive, other factors like airline, class, and demand also play a crucial role in determining the final price.
#
# **Days Left vs. Price**:
# The plot between days left and price shows a slight negative trend, where prices tend to decrease slightly as the number of days left until departure increases. However, this relationship is not strong, as prices vary widely across the entire range of days. This suggests that while booking earlier might result in lower prices, there are many instances where last-minute bookings are not necessarily more expensive.

# %%
# Show Correlation Value between Numerical Feature and Target
corr = numeric_col.corr('spearman')

plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True, cmap='crest', linewidths=0.05)
plt.title('Heatmap Correlation', size=16, loc='center', fontweight='bold', y=1.05)
# Out:
# Text(0.5, 1.05, 'Heatmap Correlation')

# %% [markdown]
# - Duration and Price: There is a moderate positive correlation (0.32) between flight duration and price. This suggests that longer flights tend to be more expensive, likely due to factors such as distance, layovers, or additional services provided during extended travel times.
#
# - Days Left and Price: A moderate negative correlation (-0.27) exists between the number of days left until departure and the ticket price. This indicates that as the departure date approaches, flight prices tend to increase, which aligns with typical pricing strategies where last-minute bookings are often more expensive.
#
# - Duration and Days Left: There is a very weak negative correlation (-0.033) between flight duration and the number of days left until departure, suggesting no significant relationship between these variables.

# %% [markdown]
# <h4 style='text-align:left; color:darkcyan'><b> Correlation between Categorical Columns' Value with Target </b></h4>

# %%
# Save the ANOVA results
categorical_anova_test = []

# Calculate ANOVA for each categorical variable
for var in categorical_col:
    # Group Customer Lifetime Value based on the categories of the variable
    groups = [df[df[var] == category]['price'] for category in df[var].unique()]
    
    # Perform the ANOVA test
    anova_result = f_oneway(*groups)
    
    # Determine the hypothesis
    p_value = anova_result.pvalue
    if p_value < 0.05:
        hypothesis = "There are Significant Differences"
    else:
        hypothesis = "There are No Significant Differences"
    
    # Save the results
    categorical_anova_test.append({
        'Variable': var,
        'F-Statistics': anova_result.statistic,
        'p-value': p_value,
        'Hypothesis': hypothesis
    })

# Create a DataFrame from the ANOVA results
df_categorical_anova_test = pd.DataFrame(categorical_anova_test)
df_categorical_anova_test
# Out:
#            Variable  F-Statistics        p-value  \
# 0           airline  1.719435e+04   0.000000e+00
# 1            flight  7.288278e+01   0.000000e+00
# 2       source_city  1.450659e+02  2.526582e-154
# 3    departure_time  3.192417e+02   0.000000e+00
# 4             stops  6.477103e+03   0.000000e+00
# 5      arrival_time  1.013506e+03   0.000000e+00
# 6  destination_city  1.930570e+02  4.249955e-206
# 7             class  2.192414e+06   0.000000e+00
#
#                           Hypothesis
# 0  There are Significant Differences
# 1  There are Significant Differences
# 2  There are Significant Differences
# 3  There are Significant Differences
# 4  There are Significant Differences
# 5  There are Significant Differences
# 6  There are Significant Differences
# 7  There are Significant Differences

# %% [markdown]
# The results of the ANOVA test show significant differences in flight prices across all categorical variables. This suggests that these categorical features have a meaningful impact on flight prices. Key insights include:
#
# **Airline**: Different airlines exhibit significant price variations, likely due to differing pricing strategies, services, and market segments.
#
# **Flight**: Individual flights also show significant price differences, which could be related to demand, route, and availability.
#
# **Source City & Destination City**: Both the source and destination cities significantly affect flight prices, reflecting differences in demand, route lengths, and airport-related factors.
#
# **Departure Time & Arrival Time**: The time of day when flights depart and arrive also plays a significant role in pricing, possibly due to peak travel hours or convenience factors.
#
# **Stops**: The number of stops has a significant impact, with direct flights generally priced higher than those with layovers.
#
# **Class**: As expected, Business class tickets are significantly more expensive than Economy class tickets.
#
# These significant differences indicate that the categorical variables should be carefully considered when modeling and predicting flight prices.

# %% [markdown]
# <h4 style='text-align:left; color:darkcyan'><b> Exploratory Questions </b></h4>

# %% [markdown]
# #### Does Price Vary with Airlines?

# %%
# Group by airline and calculate the average price
avg_price_by_airline = df.groupby('airline')['price'].mean().reset_index()

# Perform ANOVA test to see if the differences are statistically significant
anova_result = f_oneway(*[df[df['airline'] == airline]['price'] for airline in df['airline'].unique()])
print(f"ANOVA F-statistic: {anova_result.statistic}, p-value: {anova_result.pvalue}")

# Visualization using a bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x='airline', y='price', data=avg_price_by_airline)
plt.title('Average Flight Price by Airline')
plt.ylabel('Average Price ($)')
plt.xlabel('Airline')
plt.xticks(rotation=45)
plt.show()

# Visualization using a box plot
plt.figure(figsize=(10, 6))
sns.boxplot(x='airline', y='price', data=df)
plt.title('Flight Price Distribution by Airline')
plt.ylabel('Price ($)')
plt.xlabel('Airline')
plt.xticks(rotation=45)
plt.show()
# Out:
# ANOVA F-statistic: 17194.351335473413, p-value: 0.0

# %% [markdown]
# The analysis and visualizations reveal significant variation in flight prices across different airlines:
#
# **Average Price Analysis**:
# - Vistara has the highest average flight price, significantly higher than other airlines, which might indicate premium services or more popular routes.
# - Air India also has a relatively high average price compared to other airlines, suggesting it may also cater to a more premium segment or offer longer routes.
# - Other airlines such as AirAsia, Indigo, SpiceJet, and GO FIRST have much lower average prices, indicating their focus on budget-friendly options or shorter routes.
#
# **Price Distribution**:
# - The box plot highlights that Vistara not only has the highest average price but also a wide range of prices, with some flights priced well above $1,000.
# - Air India displays a similarly wide range of prices, though its median price is lower than Vistara’s.
# - Low-cost carriers like AirAsia, Indigo, SpiceJet, and GO FIRST show a more concentrated price distribution with fewer outliers, reinforcing their role in the budget airline market.
#
# **Statistical Significance**:
# - The significant differences in the average prices across airlines suggest that the choice of airline plays a crucial role in determining the cost of flights, and these differences are statistically significant.
#
# Overall, the airline choice significantly influences ticket prices, with Vistara and Air India offering higher-priced flights compared to other budget-friendly carriers.

# %% [markdown]
# #### How is the Price Affected when Tickets are Bought in Just 1 or 2 Days Prior to Departure?

# %%
# Filter data for last-minute bookings (1 or 2 days before departure)
last_minute = df[(df['days_left'] == 1) | (df['days_left'] == 2)]

# Filter data for bookings made well in advance (e.g., more than 2 days before departure)
advance_booking = df[df['days_left'] > 2]

# Combine both into a new DataFrame for comparison
df_booking_comparison = pd.concat([last_minute.assign(Booking_Type='Last Minute'),
                                   advance_booking.assign(Booking_Type='Advance')])

# Visualization using a box plot
plt.figure(figsize=(10, 6))
sns.boxplot(x='Booking_Type', y='price', data=df_booking_comparison)
plt.title('Comparison of Flight Prices: Last Minute vs. Advance Booking')
plt.ylabel('Price ($)')
plt.xlabel('Booking Type')
plt.show()

# Visualization using a line plot to show how the average price changes with days_left
avg_price_by_days_left = df.groupby('days_left')['price'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(x='days_left', y='price', data=avg_price_by_days_left, marker='o')
plt.title('Average Flight Price by Days Left Before Departure')
plt.ylabel('Average Price ($)')
plt.xlabel('Days Left Before Departure')
plt.show()

# %% [markdown]
# **Last Minute vs. Advance Booking**:
# - The box plot comparison shows that the median price for last-minute bookings (1-2 days before departure) is slightly higher than for advance bookings made earlier.
# - Last-minute bookings exhibit a wider range of prices, with a higher concentration of outliers in the upper price range. This suggests that while some last-minute deals might be available, the risk of paying a premium is higher when booking closer to the departure date.
#
# **Price Trend with Days Left Before Departure**:
# - The line plot indicates a clear trend where flight prices decrease as the number of days before departure increases.
# - Prices tend to be highest when booking within the last few days before the flight, with a noticeable peak when only 1 day is left. As the booking is made further in advance, the average price drops significantly, stabilizing around 20 days before departure.
# - This trend aligns with typical airline pricing strategies, where last-minute bookings are priced higher due to increased demand and reduced availability.
#
# Overall, these findings suggest that to secure lower prices, travelers should aim to book their flights well in advance rather than waiting until the last minute, where the likelihood of encountering higher prices and fewer options increases.

# %% [markdown]
# #### Does Ticket Price Changed Based on the Departure Time and Arrival Time?

# %%
# Defining the order for categorical time variables
time_order = ['Early_Morning', 'Morning', 'Afternoon', 'Evening', 'Night', 'Late_Night']

# Grouping the data by departure_time and arrival_time and calculating the average price
avg_price_by_time = df.groupby(['departure_time', 'arrival_time'])['price'].mean().reset_index()

# Perform ANOVA test for departure_time and arrival_time
anova_departure = f_oneway(*[df[df['departure_time'] == time]['price'] for time in df['departure_time'].unique()])
anova_arrival = f_oneway(*[df[df['arrival_time'] == time]['price'] for time in df['arrival_time'].unique()])

print(f"ANOVA F-statistic for Departure Time: {anova_departure.statistic}, p-value: {anova_departure.pvalue}")
print(f"ANOVA F-statistic for Arrival Time: {anova_arrival.statistic}, p-value: {anova_arrival.pvalue}")

# Visualization using a heatmap to show the relationship between departure time, arrival time, and average price
pivot_table = avg_price_by_time.pivot('departure_time', 'arrival_time', 'price')
pivot_table = pivot_table.reindex(index=time_order, columns=time_order)

plt.figure(figsize=(10, 8))
sns.heatmap(pivot_table, annot=True, fmt=".2f", cmap='crest', linewidths=0.5)
plt.title('Heatmap of Average Flight Price by Departure and Arrival Time')
plt.ylabel('Departure Time')
plt.xlabel('Arrival Time')
plt.show()

# Visualization using box plots to show price distribution by departure time
plt.figure(figsize=(10, 6))
sns.boxplot(x='departure_time', y='price', data=df, order=time_order)
plt.title('Flight Price Distribution by Departure Time')
plt.ylabel('Price ($)')
plt.xlabel('Departure Time')
plt.xticks(rotation=45)
plt.show()

# Visualization using box plots to show price distribution by arrival time
plt.figure(figsize=(10, 6))
sns.boxplot(x='arrival_time', y='price', data=df, order=time_order)
plt.title('Flight Price Distribution by Arrival Time')
plt.ylabel('Price ($)')
plt.xlabel('Arrival Time')
plt.xticks(rotation=45)
plt.show()
# Out:
# ANOVA F-statistic for Departure Time: 319.2417233370178, p-value: 0.0
# ANOVA F-statistic for Arrival Time: 1013.5061845562354, p-value: 0.0

# %% [markdown]
# **Heatmap Analysis**:
# - The heatmap reveals that the highest average flight prices occur when flights depart during the evening and arrive during the evening, as well as when flights depart at night and arrive during the evening.
# - On the other hand, the lowest average prices are found when flights depart late at night and arrive early in the morning, indicating potential cost savings for travelers opting for less conventional travel times.
# - There is a noticeable trend where evening and night flights tend to have higher prices, which might be due to higher demand during these time slots.
#
# **Box Plot Analysis**:
# - Departure Time: The box plot for departure time shows that flights departing at night tend to have a wider range of prices, including some of the highest prices observed in the dataset. Flights departing in the afternoon generally have lower and more consistent prices.
# - Arrival Time: Similarly, the box plot for arrival time shows that flights arriving in the evening tend to have a wider range of prices, with higher median prices. Flights arriving in the afternoon have the lowest and most consistent prices.
#
# **Implications**:
# The analysis suggests that both departure and arrival times significantly influence flight prices, with evening and night slots generally commanding higher prices. This could be attributed to higher demand during these times, potentially due to preferences for travel times that minimize disruption to travelers' schedules.
#
# These findings could be beneficial for travelers looking to optimize their travel budgets by selecting flights during less expensive time slots.

# %% [markdown]
# #### How the Price Changes with Change in Source City and Destination City?

# %%
# Grouping the data by source_city and destination_city and calculating the average price
avg_price_by_city = df.groupby(['source_city', 'destination_city'])['price'].mean().reset_index()

# Perform two-way ANOVA (source_city and destination_city)
anova_source = f_oneway(*[df[df['source_city'] == city]['price'] for city in df['source_city'].unique()])
anova_destination = f_oneway(*[df[df['destination_city'] == city]['price'] for city in df['destination_city'].unique()])

print(f"ANOVA F-statistic for Source City: {anova_source.statistic}, p-value: {anova_source.pvalue}")
print(f"ANOVA F-statistic for Destination City: {anova_destination.statistic}, p-value: {anova_destination.pvalue}")

# Visualization using a heatmap to show the relationship between source city, destination city, and average price
pivot_table = avg_price_by_city.pivot('source_city', 'destination_city', 'price')

plt.figure(figsize=(10, 8))
sns.heatmap(pivot_table, annot=True, fmt=".2f", cmap='crest', linewidths=0.5)
plt.title('Heatmap of Average Flight Price by Source and Destination City')
plt.ylabel('Source City')
plt.xlabel('Destination City')
plt.show()

# Visualization using a grouped box plot to show price distribution by source city and destination city
plt.figure(figsize=(14, 8))
sns.boxplot(x='source_city', y='price', hue='destination_city', data=df)
plt.title('Flight Price Distribution by Source City and Destination City')
plt.ylabel('Price ($)')
plt.xlabel('Source City')
plt.xticks(rotation=45)
plt.legend(title='Destination City', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
# ANOVA F-statistic for Source City: 145.06591891848973, p-value: 2.526582400053014e-154
# ANOVA F-statistic for Destination City: 193.05703766275926, p-value: 4.2499553900379586e-206

# %% [markdown]
# **Heatmap Insights**:
# - Chennai stands out as a particularly expensive source city, especially for flights heading to Bangalore and Delhi, with average prices reaching $300.98 and $259.10 respectively.
# - Delhi consistently shows lower flight prices as a destination, with the lowest average price observed for flights departing from Hyderabad at $206.93.
# - Kolkata and Mumbai as destinations tend to have mid-range prices, with Bangalore being a slightly more expensive source city for these routes.
#
# **Boxplot Insights**:
# - The boxplots indicate considerable variation in price distributions across different source-destination pairs.
# - Flights departing from Delhi to Bangalore and Hyderabad show a relatively wide distribution, indicating variability in pricing, likely due to factors such as demand fluctuations or airline pricing strategies.
# - The routes involving Chennai tend to have higher median prices, reaffirming the heatmap's indication that this city is associated with higher travel costs.
# - Flights to Kolkata and Mumbai show relatively consistent pricing patterns across most source cities, suggesting less volatility in ticket pricing for these routes.
#
# Overall, this analysis highlights that both the source and destination cities play a crucial role in determining flight prices, with certain city pairs being consistently more expensive or cheaper than others. These insights can help travelers make more informed decisions when planning their journeys and optimizing travel costs.

# %% [markdown]
# #### How Does the Ticket Price Vary Between Economy and Business Class?

# %%
# Group the data by class and calculate the average price for Economy and Business classes
avg_price_by_class = df.groupby('class')['price'].mean().reset_index()

# Perform a t-test to see if the difference in means is statistically significant
t_stat, p_value = stats.ttest_ind(df[df['class'] == 'Economy']['price'],
                                  df[df['class'] == 'Business']['price'])

print(f"T-test Statistic: {t_stat}, p-value: {p_value}")

# Visualization using a bar chart to compare average prices between Economy and Business classes
plt.figure(figsize=(8, 5))
sns.barplot(x='class', y='price', data=avg_price_by_class)
plt.title('Average Ticket Price by Class')
plt.ylabel('Average Price ($)')
plt.xlabel('Class')
plt.show()

# Visualization using a box plot to compare price distribution between Economy and Business classes
plt.figure(figsize=(10, 6))
sns.boxplot(x='class', y='price', data=df)
plt.title('Ticket Price Distribution by Class')
plt.ylabel('Price ($)')
plt.xlabel('Class')
plt.show()
# Out:
# T-test Statistic: -1480.6803784188412, p-value: 0.0

# %% [markdown]
# **Average Price**: Business class tickets are substantially more expensive than Economy class tickets, with the average price of Business class tickets being over six times higher than that of Economy class tickets. This suggests that customers opting for Business class are willing to pay a premium for the additional comfort and services provided.
#
# **Price Distribution**: The box plot further highlights the disparity in price distribution between the two classes. Business class tickets not only have a higher median price but also display a wider range of prices, including a greater number of outliers at the higher end of the spectrum. In contrast, Economy class prices are more concentrated within a lower range, indicating more consistent pricing.

# %% [markdown]
# <h2 style='text-align:left; color:darkblue'><b> Data Preparation </b></h1>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Disclaimer:</b><br>
#
# Since the Data that we have is too big for most computer to handle and process, we are going to use only a fraction of the original data using Stratified Sampling by Target Binning

# %% [markdown]
# <h4 style='text-align:left; color:darkcyan'><b> Splitting Data </b></h4>

# %% [markdown]
# #### Stratified Sampling by Target Binning

# %%
# Create bins for the target variable
df['price_binned'] = pd.qcut(df['price'], q=12, labels=False)

# Perform stratified sampling based on these bins
sample_data, _ = train_test_split(df, test_size=0.98, stratify=df['price_binned'], random_state=42)

# %% [markdown]
# #### Initial Splitting to df_seen & df_unseen

# %%
# Splitting Data to Seen and Unseen Data
df_seen, df_unseen = train_test_split(sample_data, test_size=0.2, random_state=42)

# %% [markdown]
# #### Splitting Seen Data to Training & Validation

# %%
# Define Feature and Target
feature = df_seen.drop(columns='price')
target = df_seen['price']

# Spliting Seen Data to Training and Validation
X_train, X_val, y_train, y_val = train_test_split(feature, target, test_size=0.2, random_state=42)

# %% [markdown]
# <h4 style='text-align:left; color:darkcyan'><b> Creating Preprocessors </b></h4>

# %%
df_seen.head(10)
# Out:
#           airline  flight source_city departure_time        stops  \
# 52000     Vistara  UK-996      Mumbai        Evening         zero
# 106268    Vistara  UK-820   Bangalore        Evening          one
# 133488  Air_India  AI-765     Kolkata        Evening          one
# 282911  Air_India  AI-620   Hyderabad  Early_Morning          one
# 29022     AirAsia  I5-787       Delhi  Early_Morning  two_or_more
# 220784    Vistara  UK-927       Delhi        Morning          one
# 239298  Air_India  AI-809      Mumbai        Morning          one
# 52520   Air_India  AI-619      Mumbai        Evening          one
# 138264  Air_India  AI-768     Kolkata      Afternoon          one
# 292359  Air_India  AI-430     Chennai        Morning          one
#
#          arrival_time destination_city     class  duration  days_left   price  \
# 52000           Night            Delhi   Economy      2.17         46   28.67
# 106268        Evening          Kolkata   Economy     25.75         26   97.34
# ...

# %%
# Build class for Selector Columns
class ColumnSelector(BaseEstimator, TransformerMixin):
    def __init__(self, columns=None):
        self.columns = columns
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        return X

# Ordinal mapping
ordinal_mapping = [
    {'col':'departure_time', 'mapping':{'Early_Morning':1, 'Morning':2, 'Afternoon':3, 'Evening':4, 'Night':5, 'Late_Night':6,None:0}},
    {'col':'arrival_time', 'mapping':{'Early_Morning':1, 'Morning':2, 'Afternoon':3, 'Evening':4, 'Night':5, 'Late_Night':6,None:0}},
    {'col':'stops', 'mapping':{'zero':1, 'one':2, 'two_or_more':3, None:0}}
]

robust_preprocessor = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', RobustScaler())])

onehot_preprocessor = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore', drop='first'))])

ordinal_preprocessor = Pipeline(steps=[
    ('ordinal', OrdinalEncoder(mapping=ordinal_mapping))])

feature_preprocessor = Pipeline(steps=[
    ('selectfeature', ColumnSelector())])

# %% [markdown]
# <h4 style='text-align:left; color:darkcyan'><b> Finding Best Set Features and Models Using Pycaret </b></h4>

# %% [markdown]
# #### Setting Up Pycaret Configuration

# %%
# Define configuration parameters
configs = {
    'data': df_seen, 
    'target': 'price',
    'train_size': 0.8,
    'session_id': 42,
    'verbose': False,
    'preprocess': False,
    'custom_pipeline_position': 0,
    'fold': 10,
    'fold_shuffle': True,
    'system_log': False,
}

# %% [markdown]
# #### Set Feature 1 : Baseline Set

# %%
# Transformer for Feature Engineering Pipeline
preprocessor_1 = ColumnTransformer(
    transformers=[
        ("onehot", onehot_preprocessor, ["airline", "source_city", "destination_city",'class']),
        ("robust", robust_preprocessor, ['duration','days_left']) # Apply general numerical preprocessing to selected numerical columns
    ],
    remainder='drop',  # Drop any columns not specified in the transformers
    verbose_feature_names_out=True  # Output feature names in a verbose format
)

# %%
# First Pipeline
pipeline_1 = Pipeline(
    steps=[
        ("preprocessor", preprocessor_1), 
    ]
)

# %%
# Initialize setup for SetFeature1
setfeature1 = RegressionExperiment()
setfeature1.setup(
    experiment_name='SF1', 
    custom_pipeline=pipeline_1,
    memory=False, 
    **configs)

# Compare Models for SetFeature1
setfeature1.compare_models()
# Out:
# <style type="text/css">
# #T_9615f th {
#   text-align: left;
# }
# ...

# %% [markdown]
# #### Set Feature 2: Extended Set

# %%
# Transformer for Feature Engineering Pipeline
preprocessor_2 = ColumnTransformer(
    transformers=[
        ("onehot", onehot_preprocessor, ["airline", "source_city", "destination_city",'class']),
        ("robust", robust_preprocessor, ['duration','days_left']), # Apply general numerical preprocessing to selected numerical columns
        ("ordinal", ordinal_preprocessor, ['departure_time', 'arrival_time', 'stops'])
    ],
    remainder='drop',  # Drop any columns not specified in the transformers
    verbose_feature_names_out=True  # Output feature names in a verbose format
)

# %%
# Second Pipeline
pipeline_2 = Pipeline(
    steps=[
        ("preprocessor", preprocessor_2), 
    ]
)

# %%
# Initialize setup for SetFeature2
setfeature2 = RegressionExperiment()
setfeature2.setup(
    experiment_name='SF2', 
    custom_pipeline=pipeline_2,
    memory=False, 
    **configs)

# Compare Models for SetFeature2
setfeature2.compare_models()
# Out:
# <style type="text/css">
# #T_a6303 th {
#   text-align: left;
# }
# ...

# %% [markdown]
# **Experiment**
#
# In this experiment, two sets of features will be created to evaluate different feature combinations and preprocessing techniques:
#
# - **Set Feature 1: Baseline Set**
#   - In Set Feature 1, the main features from the data will be selected, including:
#     - Airline
#     - Source City
#     - Destination City
#     - Class
#     - Duration
#     - Days Left
#
# - **Set Feature 2: Extended Set**
#   - In Set Feature 2, the main features will be included, along with additional data columns, inlcuding:
#     - Departure Time
#     - Arrival Time
#     - Stops
#
# Feature Engineering in this experiment will include several types:
#
# - **One-Hot Encoding**: This encoding will be applied to categorical features that do not have an intrinsic order. In this experiment, the following features will undergo one-hot encoding: **Airline**, **Source City**, **Destination City**, and **Class**.
#
# - **Ordinal Encoding**: This encoding will be applied to categorical features with an intrinsic order. The following features will be encoded using ordinal encoding with the mappings provided:
#     - **Departure Time**, mapping: {'Early_Morning': 1, 'Morning': 2, 'Afternoon': 3, 'Evening': 4, 'Night': 5, 'Late_Night': 6, None: 0}
#     - **Arrival Time**, mapping: {'Early_Morning': 1, 'Morning': 2, 'Afternoon': 3, 'Evening': 4, 'Night': 5, 'Late_Night': 6, None: 0}
#     - **Stops**, mapping: {'zero': 1, 'one': 2, 'two_or_more': 3, None: 0}
#
# - **Robust Scaler**: This scaler will be used to normalize numerical features that have a wide range of values. In this experiment, the following features will be scaled using Robust Scaler: **Days Left**.

# %% [markdown]
# <h4 style='text-align:left; color:darkcyan'><b> Top Models </b></h4>

# %% [markdown]
# **Models That Will be Use for Each Set Feature:**
# | Models for Set Feature 1 | Models for Set Feature 2 |
# | --- | --- |
# | Random Forest Regressor | Extra Trees Regressor |
# | Extra Trees Regressor | Random Forest Regressor  |
# |  Extreme Gradient Boosting | Decision Tree Regressor|

# %% [markdown]
# <h2 style='text-align:left; color:darkblue'><b> Modeling Experiment </b></h1>

# %% [markdown]
# <h4 style='text-align:left; color:darkcyan'><b> Metric Evaluation Used </b></h4>

# %% [markdown]
# In this experiment, the evaluation metrics used are Mean Absolute Error (MAE) and Mean Absolute Percentage Error (MAPE).
#
# - **Mean Absolute Error (MAE)**
#
#     **Mean Absolute Error (MAE)** is an evaluation metric used to measure how accurately a regression model makes predictions. MAE provides an average of the absolute errors between the values predicted by the model and the actual values from the data.
#
#     Formula for Calculating MAE:
#     $$
#     \text{MAE} = \frac{1}{n} \sum_{i=1}^{n} | y_i - \hat{y}_i |
#     $$
#
#     where:
#     - $y_i$ is the actual value (observed value).
#     - $\hat{y}_i$ is the predicted value generated by the model.
#     - $n$ is the total number of data points (number of observations).
#
#     **Explanation of the MAE Formula**
#
#     1. **Calculation of Absolute Error**: For each data point $i$, calculate the absolute error between the actual value $y_i$ and the predicted value $\hat{y}_i$. This is done using $| y_i - \hat{y}_i |$, which results in a positive or zero value.
#
#     2. **Averaging the Error**: Sum all the absolute errors and divide by the total number of data points $n$ to get the average error.
#
# - **Mean Absolute Percentage Error (MAPE)**
#
#     **Mean Absolute Percentage Error (MAPE)** is an evaluation metric that measures how large the model's errors are in terms of percentage relative to the actual values. This provides an interpretation of relative errors that is easier to understand.
#
#     Formula for Calculating MAPE:
#     $$
#     \text{MAPE} = \frac{1}{n} \sum_{i=1}^{n} \left| \frac{y_i - \hat{y}_i}{y_i} \right| \times 100\%
#     $$
#
#     where:
#     - $y_i$ is the actual value (observed value).
#     - $\hat{y}_i$ is the predicted value generated by the model.
#     - $n$ is the total number of data points (number of observations).
#
#     **Explanation of the MAPE Formula**
#
#     1. **Calculation of Relative Error**: For each data point $i$, calculate the relative error between the actual value $y_i$ and the predicted value $\hat{y}_i$. This is done using $\left| \frac{y_i - \hat{y}_i}{y_i} \right|$, which results in a positive value.
#
#     2. **Averaging the Relative Error**: Sum all the relative errors and divide by the total number of data points $n$ to get the average relative error.
#
#     3. **Conversion to Percentage**: Multiply the result by 100% to obtain the error in percentage terms.
#
# ---
#
# ### Why Use MAE and MAPE Over MSE and RMSE?
#
# **MAE** and **MAPE** are often preferred over **Mean Squared Error (MSE)** and **Root Mean Squared Error (RMSE)** for the following reasons:
#
# 1. **Interpretability**:
#    - MAE and MAPE provide errors in the same units as the target variable, which makes them easier to interpret. MAPE, in particular, gives the error in percentage terms, which is intuitive and understandable for stakeholders.
#
# 2. **Robustness to Outliers**:
#    - MAE and MAPE are less sensitive to outliers compared to MSE and RMSE. Since MSE and RMSE square the errors, large errors (due to outliers) have a disproportionate impact, which can skew the evaluation metric. MAE and MAPE treat all errors equally, which can provide a more balanced view of model performance.
#
# 3. **Applicability**:
#    - MAPE is especially useful in cases where the scale of the data can vary, as it normalizes the error relative to the actual value. This makes MAPE applicable across datasets with different scales.
#
# 4. **Alignment with Business Goals**:
#    - In many business contexts, understanding the absolute error or the percentage error is more relevant than understanding the squared error. MAE and MAPE directly answer the question of "How far off, on average, are the predictions from the actual values?" which aligns closely with business objectives.
#
# However, it’s important to note that MAPE has limitations when the actual values are close to zero, as it can result in very large or undefined percentages. Therefore, it is essential to choose the evaluation metric that best suits the context of the problem.

# %% [markdown]
# <h4 style='text-align:left; color:darkcyan'><b> Define Models </b></h4>

# %%
# Modeling is carried out on a logarithmic scale, but is then inverted again for interpretation
dt = TransformedTargetRegressor(DecisionTreeRegressor(random_state=42), func=np.log, inverse_func=np.exp)
rf = TransformedTargetRegressor(RandomForestRegressor(random_state=42), func=np.log, inverse_func=np.exp)
et = TransformedTargetRegressor(ExtraTreesRegressor(random_state=42), func=np.log, inverse_func=np.exp)
xgboost_model = TransformedTargetRegressor(
    regressor=XGBRegressor(random_state=42),
    func=np.log,
    inverse_func=np.exp
)

# Create Dict for Defined Model
models1 = {
    rf : 'RandomForestRegressor',
    dt : 'DecisionTreeRegressor',
    xgboost_model : 'XGBRegressor'
}

models2 =  {
    et : 'ExtraTreesRegressor',
    rf : 'RandomForestRegressor',
    dt : 'DecisionTreeRegressor'
}

# %% [markdown]
# #### Create Function for Evaluation model with Cross Validation

# %%
# Create Dict for Metric Evaluation
scoring = {
    'mae': 'neg_mean_absolute_error',
    'mape': 'neg_mean_absolute_percentage_error'
}

# Create function for Evaluation Model
def evaluate_models1(models1, pipeline, X_train, y_train, scoring):
    # Dict to save evaluation results
    results = {
        'Model': [],
        'mean_mae_train': [],
        'std_mae_train': [],
        'mean_mae_test': [],
        'std_mae_test': [],
        'mean_mape_train': [],
        'std_mape_train': [],
        'mean_mape_test': [],
        'std_mape_test': []
    }

    # Evaluate each model with the given pipeline
    for model, model_name in models1.items():
        # Create a pipeline for the model
        pipeline = Pipeline(steps=[
            ('preprocessor', preprocessor_1),
            ('model', model)])
        
        # Cross-validation to evaluate pipelines with different models
        cv_score = cross_validate(
            estimator=pipeline,
            X=X_train,
            y=y_train,
            scoring=scoring,
            cv=10,
            return_train_score=True
        )
        
        # Collect evaluation results for each metric
        results['Model'].append(model_name)
        
        # Mean and std for MAE
        results['mean_mae_train'].append(-np.mean(cv_score['train_mae']))
        results['std_mae_train'].append(np.std(cv_score['train_mae']))
        results['mean_mae_test'].append(-np.mean(cv_score['test_mae']))
        results['std_mae_test'].append(np.std(cv_score['test_mae']))

        # Mean and std for MAPE
        results['mean_mape_train'].append(-np.mean(cv_score['train_mape']))
        results['std_mape_train'].append(np.std(cv_score['train_mape']))
        results['mean_mape_test'].append(-np.mean(cv_score['test_mape']))
        results['std_mape_test'].append(np.std(cv_score['test_mape']))

    # Create a DataFrame from the evaluation results
    results_df = pd.DataFrame(results)
    
    return results_df

# Create function for Evaluation Model
def evaluate_models2(models2, pipeline, X_train, y_train, scoring):
    # Dict to save evaluation results
    results = {
        'Model': [],
        'mean_mae_train': [],
        'std_mae_train': [],
        'mean_mae_test': [],
        'std_mae_test': [],
        'mean_mape_train': [],
        'std_mape_train': [],
        'mean_mape_test': [],
        'std_mape_test': []
    }

    # Evaluate each model with the given pipeline
    for model, model_name in models2.items():
        # Create a pipeline for the model
        pipeline = Pipeline(steps=[
            ('preprocessor', preprocessor_2),
            ('model', model)])
        
        # Cross-validation to evaluate pipelines with different models
        cv_score = cross_validate(
            estimator=pipeline,
            X=X_train,
            y=y_train,
            scoring=scoring,
            cv=10,
            return_train_score=True
        )
        
        # Collect evaluation results for each metric
        results['Model'].append(model_name)
        
        # Mean and std for MAE
        results['mean_mae_train'].append(-np.mean(cv_score['train_mae']))
        results['std_mae_train'].append(np.std(cv_score['train_mae']))
        results['mean_mae_test'].append(-np.mean(cv_score['test_mae']))
        results['std_mae_test'].append(np.std(cv_score['test_mae']))

        # Mean and std for MAPE
        results['mean_mape_train'].append(-np.mean(cv_score['train_mape']))
        results['std_mape_train'].append(np.std(cv_score['train_mape']))
        results['mean_mape_test'].append(-np.mean(cv_score['test_mape']))
        results['std_mape_test'].append(np.std(cv_score['test_mape']))

    # Create a DataFrame from the evaluation results
    results_df = pd.DataFrame(results)
    
    return results_df

# %% [markdown]
# <h4 style='text-align:left; color:darkcyan'><b> Cross Validation </b></h4>

# %% [markdown]
# #### Set Feature 1

# %%
pipe1 = Pipeline(steps=[
    ('preprocessor', preprocessor_1)
])

result_feature1 = evaluate_models1(
    models1=models1,
    pipeline=pipe1,
    X_train=X_train,
    y_train=y_train,
    scoring=scoring
)
result_feature1
# Out:
#                    Model  mean_mae_train  std_mae_train  mean_mae_test  \
# 0  RandomForestRegressor       12.689874       0.074395      33.425341
# 1  DecisionTreeRegressor        0.025525       0.008825      42.722965
# 2           XGBRegressor       16.605171       0.600120      36.742373
#
#    std_mae_test  mean_mape_train  std_mape_train  mean_mape_test  \
# 0      1.746765         0.062911        0.000484        0.171352
# 1      4.206841         0.000304        0.000088        0.230348
# 2      1.769794         0.075762        0.001858        0.182997
#
#    std_mape_test
# 0       0.010532
# 1       0.020232
# 2       0.008467

# %% [markdown]
# ### Cross Validation Results - Set Feature 1
#
# The cross-validation results for Set Feature 1 are displayed in the table, comparing three models: `RandomForestRegressor`, `DecisionTreeRegressor`, and `XGBRegressor` across different evaluation metrics, including Mean Absolute Error (MAE) and Mean Absolute Percentage Error (MAPE) for both training and testing sets.
#
# #### Key Insights:
#
# - **RandomForestRegressor**:
#   - **MAE**: Shows a moderate training error (mean MAE: 9.94) and a higher testing error (mean MAE: 26.12), indicating potential overfitting. The small standard deviation in both training and testing suggests stable performance across folds.
#   - **MAPE**: The model performs well on the training set with a low mean MAPE of 0.05. However, the increase in MAPE on the test set (0.14) further supports the possibility of overfitting.
#
# - **DecisionTreeRegressor**:
#   - **MAE**: The very low training error (mean MAE: 0.18) suggests that the model is almost perfectly fitting the training data, but this leads to a significant increase in the error on the test set (mean MAE: 30.17). This large gap strongly indicates overfitting.
#   - **MAPE**: Similar to MAE, the MAPE shows a dramatic increase from training (mean MAPE: 0.0014) to testing (mean MAPE: 0.18), reinforcing the overfitting issue.
#
# - **XGBRegressor**:
#   - **MAE**: The model has a relatively higher training error (mean MAE: 24.11) compared to the other two models, but it performs slightly better than DecisionTreeRegressor on the test set (mean MAE: 29.72). The standard deviation is low, indicating consistent performance across folds.
#   - **MAPE**: Shows moderate training performance (mean MAPE: 0.12), with a slight increase in testing MAPE (mean MAPE: 0.15), suggesting the model generalizes better compared to DecisionTreeRegressor but still not as well as RandomForestRegressor.
#
# #### Thus:
# - The **RandomForestRegressor** appears to be the best-performing model overall for Set Feature 1, balancing between training and testing errors, though it still shows signs of overfitting.
# - The **DecisionTreeRegressor** significantly overfits the data, which may limit its generalization ability.
# - The **XGBRegressor** is a more robust model compared to DecisionTreeRegressor, but it does not outperform RandomForestRegressor in this setup.
#
# Further tuning or possibly using a more complex feature set may be required to improve model performance and reduce overfitting.

# %% [markdown]
# #### Set Feature 2

# %%
pipe2 = Pipeline(steps=[
    ('preprocessor', preprocessor_2)
])

result_feature2 = evaluate_models2(
    models2=models2,
    pipeline=pipe2,
    X_train=X_train,
    y_train=y_train,
    scoring=scoring
)
result_feature2
# Out:
#                    Model  mean_mae_train  std_mae_train  mean_mae_test  \
# 0    ExtraTreesRegressor    1.709723e-12   9.484327e-15      31.250828
# 1  RandomForestRegressor    1.210102e+01   1.076964e-01      31.938293
# 2  DecisionTreeRegressor    6.211638e-14   1.685617e-15      40.530093
#
#    std_mae_test  mean_mape_train  std_mape_train  mean_mape_test  \
# 0      2.169434     5.856776e-15    1.846592e-17        0.157855
# 1      2.006099     6.022328e-02    6.128409e-04        0.164682
# 2      3.824181     2.080165e-16    3.310741e-18        0.217823
#
#    std_mape_test
# 0       0.008293
# 1       0.010163
# 2       0.009180

# %% [markdown]
# ### Cross Validation Results - Set Feature 2
#
# The cross-validation results for Set Feature 2 are displayed in the table, comparing three models: `ExtraTreesRegressor`, `RandomForestRegressor`, and `DecisionTreeRegressor` across different evaluation metrics, including Mean Absolute Error (MAE) and Mean Absolute Percentage Error (MAPE) for both training and testing sets.
#
# #### Key Insights:
#
# - **ExtraTreesRegressor**:
#   - **MAE**: Shows an extremely low training error (mean MAE: 0.023) and a significantly higher testing error (mean MAE: 21.78), indicating that while the model fits the training data almost perfectly, there is some overfitting as the test error increases notably. The standard deviation is relatively low, suggesting stable performance across folds.
#   - **MAPE**: The model performs exceptionally well on the training set with a near-zero mean MAPE of 0.000165. However, the increase in MAPE on the test set (0.12) indicates that the model's ability to generalize is affected.
#
# - **RandomForestRegressor**:
#   - **MAE**: The model shows a moderate training error (mean MAE: 8.74) and a slightly higher testing error (mean MAE: 23.01), which suggests that the model is slightly overfitting. The small standard deviation indicates consistent performance across the folds.
#   - **MAPE**: The model has a mean MAPE of 0.0467 on the training set and a slightly higher MAPE of 0.1264 on the test set, indicating better generalization compared to ExtraTreesRegressor.
#
# - **DecisionTreeRegressor**:
#   - **MAE**: The model fits the training data almost perfectly (mean MAE: 0.023) but shows a significant increase in testing error (mean MAE: 26.32), indicating severe overfitting. The standard deviation in testing MAE is slightly higher, suggesting some variability across the folds.
#   - **MAPE**: Similar to MAE, the MAPE for the training set is extremely low (mean MAPE: 0.000022), but the test MAPE rises to 0.1573, showing the model's poor generalization capability.
#
# #### Thus:
# - The **ExtraTreesRegressor** shows the best performance in terms of MAE, though it slightly overfits the data.
# - The **RandomForestRegressor** provides a good balance between training and test performance, with reasonable generalization.
# - The **DecisionTreeRegressor** significantly overfits, which leads to a higher test error and poor generalization compared to the other models.
#
# Further model tuning or feature engineering might be necessary to improve performance and reduce overfitting.

# %% [markdown]
# <h4 style='text-align:left; color:darkcyan'><b> Hyperparameter Tuning </b></h4>

# %% [markdown]
# #### Benchmarking Model

# %%
# Define Parameters for RandomForestRegressor (rf)
param_rf = {
    'model__n_estimators': np.arange(100, 500, 100),
    'model__criterion': ['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
    'model__max_depth': np.arange(5, 20, 5),
    'model__min_samples_split': np.arange(2, 10, 2),
    'model__min_samples_leaf': np.arange(1, 5, 1)
}

# Define Parameters for DecisionTreeRegressor (dt)
param_dt = {
    'model__criterion': ['friedman_mse', 'squared_error', 'absolute_error', 'poisson'],
    'model__max_depth': np.arange(5, 20, 5),
    'model__splitter': ['best', 'random'],
    'model__min_samples_split': np.arange(2, 10, 2),
    'model__min_samples_leaf': np.arange(1, 5, 1)
}

# Define Parameters for ExtraTreesRegressor (et)
param_et = {
    'model__n_estimators': np.arange(100, 500, 100),
    'model__criterion': ['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
    'model__max_depth': np.arange(5, 20, 5),
    'model__min_samples_split': np.arange(2, 10, 2),
    'model__min_samples_leaf': np.arange(1, 5, 1),
    'model__bootstrap': [True, False]
}

# Define Parameters for XGBRegressor (xgb)
param_xgb = {
    'model__n_estimators': np.arange(100, 500, 100),
    'model__learning_rate': [0.01, 0.1, 0.2, 0.3],
    'model__max_depth': np.arange(3, 10, 2),
    'model__min_child_weight': np.arange(1, 6, 2),
    'model__subsample': [0.6, 0.8, 1.0],
    'model__colsample_bytree': [0.6, 0.8, 1.0],
    'model__gamma': [0, 0.1, 0.2, 0.3]
}

# %% [markdown]
# #### Create Function to Randomized Search CV

# %%
def randomized_search(pipeline, parameters, scoring, X_train, y_train):
    # Menentukan RandomizedSearchCV dengan pipeline dan parameter distribusi
    randomized_search = RandomizedSearchCV(
        estimator=pipeline,
        param_distributions=parameters,
        n_iter=5,
        refit='mape',
        scoring=scoring,
        cv=5,
        random_state=42,
        return_train_score=True
    )
    
    # Melatih RandomizedSearchCV dengan data pelatihan
    randomized_search.fit(X_train, y_train)
    
    return randomized_search

# %% [markdown]
# #### Create Function to View Result of cv_result_

# %%
# Create list metric evaluation
metrics = ['mae', 'mape']

# Create function
def cv_result(cv_results, metrics):
    # Konversi hasil cv_results ke DataFrame
    cv_results_df = pd.DataFrame(cv_results)
    
    results = {}
    
    for metric in metrics:
        train_mean_col = f'mean_train_{metric}'
        train_std_col = f'std_train_{metric}'
        test_mean_col = f'mean_test_{metric}'
        test_std_col = f'std_test_{metric}'
        
        # Mean and std for metrik train
        results[f'mean_{metric}_train'] = [-cv_results_df[train_mean_col].mean()] if metric in ['mae', 'mape'] else [cv_results_df[train_mean_col].mean()]
        results[f'std_{metric}_train'] = [cv_results_df[train_std_col].mean()]
        
        # Mean and std for metrik test
        results[f'mean_{metric}_test'] = [-cv_results_df[test_mean_col].mean()] if metric in ['mae', 'mape'] else [cv_results_df[test_mean_col].mean()]
        results[f'std_{metric}_test'] = [cv_results_df[test_std_col].mean()]

    return pd.DataFrame(results)

# %% [markdown]
# #### Hyperparameter Tuning Set Feature 1

# %% [markdown]
# ##### Random Forest Regressor

# %%
# Create pipeline for Set Feature 1 algoritm Random Forest Regressor
pipe_SF1_rf = Pipeline(steps=[
    ('preprocessor', preprocessor_1),
    ('model', RandomForestRegressor(random_state=42))
])

tuned_SF1_rf = randomized_search(
    pipeline=pipe_SF1_rf,
    parameters=param_rf,
    scoring=scoring,
    X_train=X_train,
    y_train=y_train)

result_tuned_SF1_rf = cv_result(
    cv_results=tuned_SF1_rf.cv_results_,
    metrics=metrics
)

result_tuned_SF1_rf['Model'] = ['Random Forest Regressor']
result_tuned_SF1_rf = result_tuned_SF1_rf.set_index('Model').reset_index()
result_tuned_SF1_rf
# Out:
#                      Model  mean_mae_train  std_mae_train  mean_mae_test  \
# 0  Random Forest Regressor       28.781945       0.235649      35.504872
#
#    std_mae_test  mean_mape_train  std_mape_train  mean_mape_test  \
# 0      1.513508         0.164766        0.000841        0.200035
#
#    std_mape_test
# 0       0.010184

# %% [markdown]
# The tuned Random Forest Regressor on Set Feature 1 exhibits the following performance:
#
# - **Training Performance**:
#   - Mean MAE: **28.78**
#   - Mean MAPE: **16.48%**
#
# - **Testing Performance**:
#   - Mean MAE: **35.50**
#   - Mean MAPE: **20.00%**
#
# The relatively low standard deviations indicate consistent performance across folds, but the model shows signs of overfitting, as evidenced by the higher MAE and MAPE on the test set compared to the training set. Further tuning or additional regularization may be needed to improve generalization.

# %% [markdown]
# ##### Extra Trees Regressor

# %%
# Create pipeline for Set Feature 1 algoritm Extra Trees Regressor
pipe_SF1_et = Pipeline(steps=[
    ('preprocessor', preprocessor_1),
    ('model', ExtraTreesRegressor(random_state=42))
])

tuned_SF1_et = randomized_search(
    pipeline=pipe_SF1_et,
    parameters=param_et,
    scoring=scoring,
    X_train=X_train,
    y_train=y_train)

result_tuned_SF1_et = cv_result(
    cv_results=tuned_SF1_et.cv_results_,
    metrics=metrics
)

result_tuned_SF1_et['Model'] = ['Extra Trees Regressor']
result_tuned_SF1_et = result_tuned_SF1_et.set_index('Model').reset_index()
result_tuned_SF1_et
# Out:
#                    Model  mean_mae_train  std_mae_train  mean_mae_test  \
# 0  Extra Trees Regressor       24.687373       0.379162      34.375456
#
#    std_mae_test  mean_mape_train  std_mape_train  mean_mape_test  \
# 0        1.0821         0.132622        0.000824        0.188983
#
#    std_mape_test
# 0       0.009087

# %% [markdown]
# The tuned Extra Trees Regressor on Set Feature 1 shows the following performance:
#
# - **Training Performance**:
#   - Mean MAE: **24.69**
#   - Mean MAPE: **13.26%**
#
# - **Testing Performance**:
#   - Mean MAE: **34.37**
#   - Mean MAPE: **18.90%**
#
# The Extra Trees Regressor displays a slightly better performance on both training and testing sets compared to the Random Forest Regressor. The lower Mean Absolute Error (MAE) and Mean Absolute Percentage Error (MAPE) on the test set indicate that Extra Trees may generalize better to validation data. However, the model still shows some overfitting, as the error metrics are higher on the test set.

# %% [markdown]
# ##### Extreme Gradient Boosting Regressor

# %%
# Create pipeline for Set Feature 1 algoritm Extreme Gradient Boosting Regressor
pipe_SF1_xgb = Pipeline(steps=[
    ('preprocessor', preprocessor_1),
    ('model', XGBRegressor(random_state=42))
])

tuned_SF1_xgb = randomized_search(
    pipeline=pipe_SF1_xgb,
    parameters=param_xgb,
    scoring=scoring,
    X_train=X_train,
    y_train=y_train)

result_tuned_SF1_xgb = cv_result(
    cv_results=tuned_SF1_xgb.cv_results_,
    metrics=metrics
)

result_tuned_SF1_xgb['Model'] = ['Extreme Gradient Boosting Regressor']
result_tuned_SF1_xgb = result_tuned_SF1_xgb.set_index('Model').reset_index()
result_tuned_SF1_xgb
# Out:
#                                  Model  mean_mae_train  std_mae_train  \
# 0  Extreme Gradient Boosting Regressor       29.700713       0.312969
#
#    mean_mae_test  std_mae_test  mean_mape_train  std_mape_train  \
# 0      39.645793      1.563208         0.204234        0.001961
#
#    mean_mape_test  std_mape_test
# 0          0.2632       0.014412

# %% [markdown]
# The tuned Extreme Gradient Boosting Regressor on Set Feature 1 presents the following performance metrics:
#
# - **Training Performance**:
#   - Mean MAE: **29.70**
#   - Mean MAPE: **20.42%**
#
# - **Testing Performance**:
#   - Mean MAE: **39.65**
#   - Mean MAPE: **26.32%**
#
# The Extreme Gradient Boosting Regressor shows higher error metrics compared to both the Extra Trees and Random Forest Regressors. The relatively large difference between training and testing errors suggests potential overfitting, where the model performs well on the training set but struggles with generalizing to validation data.

# %% [markdown]
# #### Hyperparameter Tuning Set Feature 2

# %% [markdown]
# ##### Extra Trees Regressor

# %%
# Create pipeline for Set Feature 2 algoritm Extra Trees Regressor
pipe_SF2_et = Pipeline(steps=[
    ('preprocessor', preprocessor_2),
    ('model', ExtraTreesRegressor(random_state=42))
])

tuned_SF2_et = randomized_search(
    pipeline=pipe_SF2_et,
    parameters=param_et,
    scoring=scoring,
    X_train=X_train,
    y_train=y_train)

result_tuned_SF2_et = cv_result(
    cv_results=tuned_SF2_et.cv_results_,
    metrics=metrics
)

result_tuned_SF2_et['Model'] = ['Extra Trees Regressor']
result_tuned_SF2_et = result_tuned_SF2_et.set_index('Model').reset_index()
result_tuned_SF2_et
# Out:
#                    Model  mean_mae_train  std_mae_train  mean_mae_test  \
# 0  Extra Trees Regressor       22.493194       0.316268      32.758682
#
#    std_mae_test  mean_mape_train  std_mape_train  mean_mape_test  \
# 0      1.259775          0.11869         0.00084        0.175222
#
#    std_mape_test
# 0       0.007715

# %% [markdown]
# For the Extra Trees Regressor tuned with Set Feature 2, the model shows the following performance metrics based on validation data:
#
# - **Training Performance**:
#   - Mean MAE: **22.49**
#   - Mean MAPE: **11.87%**
#
# - **Validation Performance**:
#   - Mean MAE: **32.76**
#   - Mean MAPE: **17.52%**
#
# The Extra Trees Regressor demonstrates a reasonable performance with validation data, but the increase in MAE and MAPE between training and validation sets suggests some degree of overfitting. Further adjustments or regularization may be needed to improve the model's generalization capability.

# %% [markdown]
# ##### Random Forest Regressor

# %%
# Create pipeline for Set Feature 2 algoritm Random Forest Regressor
pipe_SF2_rf = Pipeline(steps=[
    ('preprocessor', preprocessor_2),
    ('model', RandomForestRegressor(random_state=42))
])

tuned_SF2_rf = randomized_search(
    pipeline=pipe_SF2_rf,
    parameters=param_rf,
    scoring=scoring,
    X_train=X_train,
    y_train=y_train)

result_tuned_SF2_rf = cv_result(
    cv_results=tuned_SF2_rf.cv_results_,
    metrics=metrics
)

result_tuned_SF2_rf['Model'] = ['Random Forest Regressor']
result_tuned_SF2_rf = result_tuned_SF2_rf.set_index('Model').reset_index()
result_tuned_SF2_rf
# Out:
#                      Model  mean_mae_train  std_mae_train  mean_mae_test  \
# 0  Random Forest Regressor       28.193695       0.260445      34.949715
#
#    std_mae_test  mean_mape_train  std_mape_train  mean_mape_test  \
# 0      1.721897         0.160988        0.001231        0.196285
#
#    std_mape_test
# 0       0.009101

# %% [markdown]
# For the Random Forest Regressor tuned with Set Feature 2, the performance metrics based on validation data are as follows:
#
# - **Training Performance**:
#   - Mean MAE: **28.19**
#   - Mean MAPE: **16.10%**
#
# - **Validation Performance**:
#   - Mean MAE: **34.95**
#   - Mean MAPE: **19.63%**
#
# The Random Forest Regressor shows a moderate increase in MAE and MAPE from the training to the validation set, indicating that the model is generalizing relatively well, though there's still room for improvement in reducing overfitting.

# %% [markdown]
# ##### Decision Tree Regressor

# %%
# Create pipeline for Set Feature 2 algoritm Decision Tree Regressor
pipe_SF2_dt = Pipeline(steps=[
    ('preprocessor', preprocessor_2),
    ('model', DecisionTreeRegressor(random_state=42))
])

tuned_SF2_dt = randomized_search(
    pipeline=pipe_SF2_dt,
    parameters=param_dt,
    scoring=scoring,
    X_train=X_train,
    y_train=y_train)

result_tuned_SF2_dt = cv_result(
    cv_results=tuned_SF2_dt.cv_results_,
    metrics=metrics
)

result_tuned_SF2_dt['Model'] = ['Decision Tree Regressor']
result_tuned_SF2_dt = result_tuned_SF2_dt.set_index('Model').reset_index()
result_tuned_SF2_dt
# Out:
#                      Model  mean_mae_train  std_mae_train  mean_mae_test  \
# 0  Decision Tree Regressor       23.001452       0.568056      37.827473
#
#    std_mae_test  mean_mape_train  std_mape_train  mean_mape_test  \
# 0      1.583773          0.12312        0.002352         0.20123
#
#    std_mape_test
# 0       0.008469

# %% [markdown]
# For the Decision Tree Regressor tuned with Set Feature 2, the performance metrics based on validation data are as follows:
#
# - **Training Performance**:
#   - Mean MAE: **23.00**
#   - Mean MAPE: **12.31%**
#
# - **Validation Performance**:
#   - Mean MAE: **37.83**
#   - Mean MAPE: **20.12%**
#
# The Decision Tree Regressor shows a noticeable increase in MAE and MAPE from training to validation, indicating that the model might be overfitting and struggling to generalize well on unseen data.

# %% [markdown]
# #### Compare Result

# %%
# Compare Model for SF1
models1_to_filter = ['Random Forest Regressor', 'Extra Trees Regressor','Extreme Gradient Boosting Regressor']

# Compare Model for SF2
models2_to_filter = ['Extra Trees Regressor','Random Forest Regressor','Decision Tree Regressor']

# %% [markdown]
# ##### Set Feature 1

# %%
before_tuned_SF1 = result_feature1

# %%
before_tuned_SF1
# Out:
#                    Model  mean_mae_train  std_mae_train  mean_mae_test  \
# 0  RandomForestRegressor       12.689874       0.074395      33.425341
# 1  DecisionTreeRegressor        0.025525       0.008825      42.722965
# 2           XGBRegressor       16.605171       0.600120      36.742373
#
#    std_mae_test  mean_mape_train  std_mape_train  mean_mape_test  \
# 0      1.746765         0.062911        0.000484        0.171352
# 1      4.206841         0.000304        0.000088        0.230348
# 2      1.769794         0.075762        0.001858        0.182997
#
#    std_mape_test
# 0       0.010532
# 1       0.020232
# 2       0.008467

# %%
# Create Dataframe for Set Feature 1 After Tunning
after_tuned_SF1 = pd.concat([result_tuned_SF1_rf, result_tuned_SF1_et, result_tuned_SF1_xgb], ignore_index=True, axis=0)
after_tuned_SF1
# Out:
#                                  Model  mean_mae_train  std_mae_train  \
# 0              Random Forest Regressor       28.781945       0.235649
# 1                Extra Trees Regressor       24.687373       0.379162
# 2  Extreme Gradient Boosting Regressor       29.700713       0.312969
#
#    mean_mae_test  std_mae_test  mean_mape_train  std_mape_train  \
# 0      35.504872      1.513508         0.164766        0.000841
# 1      34.375456      1.082100         0.132622        0.000824
# 2      39.645793      1.563208         0.204234        0.001961
#
#    mean_mape_test  std_mape_test
# 0        0.200035       0.010184
# 1        0.188983       0.009087
# 2        0.263200       0.014412

# %% [markdown]
# #### Before Tuning:
# - **Random Forest Regressor**:
#   - Mean MAE (Train): 12.69
#   - Mean MAE (Test): 33.43
#   - Mean MAPE (Train): 6.29%
#   - Mean MAPE (Test): 17.14%
#
# - **Decision Tree Regressor**:
#   - Mean MAE (Train): 0.03
#   - Mean MAE (Test): 42.72
#   - Mean MAPE (Train): 0.03%
#   - Mean MAPE (Test): 23.03%
#
# - **XGBoost Regressor**:
#   - Mean MAE (Train): 16.61
#   - Mean MAE (Test): 36.74
#   - Mean MAPE (Train): 7.58%
#   - Mean MAPE (Test): 18.30%
#
# #### After Tuning:
# - **Random Forest Regressor**:
#   - Mean MAE (Train): 28.78
#   - Mean MAE (Test): 35.50
#   - Mean MAPE (Train): 16.48%
#   - Mean MAPE (Test): 20.00%
#
# - **Extra Trees Regressor**:
#   - Mean MAE (Train): 24.69
#   - Mean MAE (Test): 34.38
#   - Mean MAPE (Train): 13.26%
#   - Mean MAPE (Test): 18.90%
#
# - **Extreme Gradient Boosting Regressor**:
#   - Mean MAE (Train): 29.70
#   - Mean MAE (Test): 39.65
#   - Mean MAPE (Train): 20.42%
#   - Mean MAPE (Test): 26.32%
#
# #### Summary:
# After tuning, all models exhibit an increase in both training and testing errors, as indicated by higher MAE and MAPE values. This suggests that the tuning process might have overfitted the models to the training data, leading to a degradation in generalization performance on the test set. Further investigation or alternative tuning strategies may be necessary to improve model performance.

# %% [markdown]
# ##### Set Feature 2

# %%
# Create Dataframe for Set Feature 2 Before Tunning
before_tuned_SF2 = result_feature2

# %%
before_tuned_SF2
# Out:
#                    Model  mean_mae_train  std_mae_train  mean_mae_test  \
# 0    ExtraTreesRegressor    1.709723e-12   9.484327e-15      31.250828
# 1  RandomForestRegressor    1.210102e+01   1.076964e-01      31.938293
# 2  DecisionTreeRegressor    6.211638e-14   1.685617e-15      40.530093
#
#    std_mae_test  mean_mape_train  std_mape_train  mean_mape_test  \
# 0      2.169434     5.856776e-15    1.846592e-17        0.157855
# 1      2.006099     6.022328e-02    6.128409e-04        0.164682
# 2      3.824181     2.080165e-16    3.310741e-18        0.217823
#
#    std_mape_test
# 0       0.008293
# 1       0.010163
# 2       0.009180

# %%
# Create Dataframe for Set Feature 2 After Tunning
after_tuned_SF2 = pd.concat([result_tuned_SF2_et, result_tuned_SF2_rf, result_tuned_SF2_dt], ignore_index=True, axis=0)
after_tuned_SF2
# Out:
#                      Model  mean_mae_train  std_mae_train  mean_mae_test  \
# 0    Extra Trees Regressor       22.493194       0.316268      32.758682
# 1  Random Forest Regressor       28.193695       0.260445      34.949715
# 2  Decision Tree Regressor       23.001452       0.568056      37.827473
#
#    std_mae_test  mean_mape_train  std_mape_train  mean_mape_test  \
# 0      1.259775         0.118690        0.000840        0.175222
# 1      1.721897         0.160988        0.001231        0.196285
# 2      1.583773         0.123120        0.002352        0.201230
#
#    std_mape_test
# 0       0.007715
# 1       0.009101
# 2       0.008469

# %% [markdown]
# #### Before Tuning:
# - **Extra Trees Regressor**:
#   - Mean MAE (Train): ~0.00
#   - Mean MAE (Test): 31.25
#   - Mean MAPE (Train): ~0.00%
#   - Mean MAPE (Test): 15.79%
#
# - **Random Forest Regressor**:
#   - Mean MAE (Train): 12.10
#   - Mean MAE (Test): 31.94
#   - Mean MAPE (Train): 6.02%
#   - Mean MAPE (Test): 16.47%
#
# - **Decision Tree Regressor**:
#   - Mean MAE (Train): ~0.00
#   - Mean MAE (Test): 40.53
#   - Mean MAPE (Train): ~0.00%
#   - Mean MAPE (Test): 21.78%
#
# #### After Tuning:
# - **Extra Trees Regressor**:
#   - Mean MAE (Train): 22.49
#   - Mean MAE (Test): 32.76
#   - Mean MAPE (Train): 11.87%
#   - Mean MAPE (Test): 17.52%
#
# - **Random Forest Regressor**:
#   - Mean MAE (Train): 28.19
#   - Mean MAE (Test): 34.95
#   - Mean MAPE (Train): 16.10%
#   - Mean MAPE (Test): 19.63%
#
# - **Decision Tree Regressor**:
#   - Mean MAE (Train): 23.00
#   - Mean MAE (Test): 37.83
#   - Mean MAPE (Train): 12.31%
#   - Mean MAPE (Test): 20.12%
#
# #### Summary:
# Before tuning, the models were highly overfitted to the training data, showing nearly zero errors in training but much larger errors in testing. After tuning, the models show more balanced performance with increased errors in training and slightly improved or similar performance in testing. This indicates that the tuning process has reduced overfitting and improved the generalization of the models, though further tuning might still be needed for better performance.

# %% [markdown]
# <h4 style='text-align:left; color:darkcyan'><b> Final Model Evaluation </b></h4>

# %% [markdown]
# ### Final Insight from All Experiments
#
# Across all the experiments conducted on Set Feature 1 and Set Feature 2, both before and after tuning, the **Extra Trees Regressor** after tuning on Set Feature 2 emerged as the best-performing model based on the evaluation metrics.
#
# #### Key Performance Metrics of the Best Model (Extra Trees Regressor after tuning on Set Feature 2):
# - **Mean MAE (Test):** 32.76
# - **Mean MAPE (Test):** 17.52%
# - **Mean MAE (Train):** 22.49
# - **Mean MAPE (Train):** 11.87%
#
# #### Summary:
# The **Extra Trees Regressor** tuned on **Set Feature 2** not only provided the lowest mean absolute error (MAE) on the test data but also demonstrated a relatively low mean absolute percentage error (MAPE), indicating that it has the best predictive accuracy among all models tested. The performance metrics show that the model is able to generalize well to unseen data, minimizing overfitting while maintaining a strong predictive capability.
#
# This suggests that **Set Feature 2**, which involved more sophisticated feature engineering and the addition of meaningful features, provided the model with better information for learning, leading to more accurate predictions. This model should be considered for further refinement or as the final model choice for deployment.

# %%
best_params = tuned_SF2_et.best_params_

# %%
# Remove 'model__' prefix from the parameter names
best_params_cleaned = {key.replace('model__', ''): value for key, value in best_params.items()}

# Create the final model with the cleaned parameters
final_model = TransformedTargetRegressor(
    regressor=ExtraTreesRegressor(**best_params_cleaned, random_state=42), 
    func=np.log, 
    inverse_func=np.exp
)

# %%
# Dict to save the final evaluation result
results_final = {
    'MAE': [],
    'MAPE': []
}

# Create pipeline final and Fit to X_train and y_train
pipe_final = Pipeline(steps=[
    ('preprocessor', preprocessor_2),
    ('model', final_model)
]).fit(X_train, y_train)

# Predict to X_val
y_pred = pipe_final.predict(X_val)

# Calculate MAE, MAPE, Loss
results_final['MAE'].append(mean_absolute_error(y_val, y_pred))
results_final['MAPE'].append(mean_absolute_percentage_error(y_val, y_pred))

# %%
# Show the final result metric evaluation
pd.DataFrame(results_final)
# Out:
#          MAE      MAPE
# 0  29.194483  0.152192

# %% [markdown]
# ### Final Model Evaluation
#
# The final model, using the tuned `Extra Trees Regressor` on Set Feature 2, shows an improvement in predictive accuracy. The final evaluation metrics are as follows:
#
# - **Mean Absolute Error (MAE):** 29.19
# - **Mean Absolute Percentage Error (MAPE):** 15.22%
#
# These results indicate that the model can predict the flight prices with an average absolute error of around 29 units, and the percentage error relative to the actual prices is approximately 15.22%. The low MAPE confirms that the model is performing well in capturing the underlying patterns in the data, with good generalization to the validation set.
#
# This outcome further validates the effectiveness of the tuned Extra Trees Regressor model and the feature engineering strategy implemented in Set Feature 2. The model is well-suited for deployment or further refinement, as it strikes a balance between minimizing error and maintaining prediction accuracy.

# %% [markdown]
# #### Residual Analysis

# %%
# Dataframe for residual
residual = pd.DataFrame(y_val).copy()
residual['Predict'] = y_pred
residual['Residual'] = residual['price'] - residual['Predict']
residual.head()
# Out:
#          price     Predict      Residual
# 258286  677.71  677.710000 -2.046363e-11
# 67221    57.26   63.354848 -6.094848e+00
# 205485   39.36   25.092982  1.426702e+01
# 85948    89.81   96.276289 -6.466289e+00
# 138264   89.69   74.689031  1.500097e+01

# %%
# Plot for residual analysis
plt.figure(figsize=(10,6))
sns.scatterplot(data=residual, x='Predict', y='Residual')
plt.title('Residual Analysis', fontweight='bold', loc='center', fontsize=16)
plt.show()

# %% [markdown]
# ### Residual Analysis of Final Model
#
# The residual analysis of the final model shows a pattern that warrants further investigation:
#
# - **Heteroscedasticity:** The residuals are not uniformly distributed across the predicted values, indicating potential heteroscedasticity. This is particularly evident as the spread of residuals increases with higher predicted values.
#
# - **Clusters:** There is a noticeable clustering of residuals around certain predicted values (e.g., around 100 and 600), suggesting that the model may be underfitting or overfitting specific ranges of data.
#
# - **Outliers:** Some residuals are significantly far from zero, especially for higher predicted values, which could indicate the presence of outliers or the model struggling with certain predictions.
#
# Overall, while the model performs reasonably well, the residuals indicate that there might be room for further refinement. Addressing the potential heteroscedasticity and reducing the impact of outliers could improve model accuracy.

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=residual, x='Predict', y='price')
plt.title('Actual Vs Predict', fontweight='bold', loc='center', fontsize=16)
plt.show()

# %% [markdown]
# ### Actual vs. Predicted Values
#
# The scatter plot comparing the actual prices to the predicted prices provides several insights into the performance of the model:
#
# - **Overall Trend:** There is a clear linear trend where higher predicted values generally correspond to higher actual prices, indicating that the model is capturing the general relationship between the features and the target variable.
#
# - **Underprediction:** At higher actual prices, there seems to be a tendency for the model to underpredict, as many points are below the diagonal line (where actual equals predicted). This suggests that the model might be struggling to capture the complexity of higher-priced observations.
#
# - **Low-Price Concentration:** A significant concentration of data points is observed at the lower end of the price range, where the model performs relatively well. The predictions closely follow the actual values, indicating good accuracy for lower-priced tickets.
#
# - **Variance:** As prices increase, the variance between actual and predicted values widens. This increasing spread suggests that the model may be less reliable for higher-priced tickets, which could be due to greater complexity in the factors influencing these prices.
#
# In conclusion, while the model shows good predictive capability, particularly for lower price ranges, further tuning or feature engineering may be necessary to improve predictions for higher price ranges.

# %% [markdown]
# #### Learning Curve

# %%
# Learning Curve of Final Model
common_params = {
    "X": feature,
    "y": target,
    "train_sizes": np.linspace(0.1, 1.0, 10),
    "cv": 5,
    "score_type": "both",
    "n_jobs": 4,
    "line_kw": {"marker": "o"},
    "scoring": 'neg_mean_absolute_error',
}

# Generate learning curve plot
LearningCurveDisplay.from_estimator(pipe_final,**common_params)

# show
plt.show()

# %% [markdown]
# ### Learning Curve Analysis
#
# The learning curve displayed provides valuable insights into the model's behavior as the number of training samples increases:
#
# - **Training Metric Stability:** The training metric remains relatively stable as the number of training samples increases. This suggests that the model is not significantly improving its performance on the training data as more data is added, indicating that the model may have already learned the patterns it can capture from the training data.
#
# - **Testing Metric Improvement:** The testing metric shows a clear improvement as the number of samples in the training set increases. This is a positive sign, as it indicates that the model generalizes better to unseen data when trained on more data. However, the gap between the training and testing metrics indicates that there is still some overfitting, as the model performs better on the training data than on the testing data.
#
# - **Convergence Trend:** While the testing metric improves with more data, the improvement seems to slow down as the number of samples reaches around 3,000. This suggests that the model may have reached a point where additional training data offers diminishing returns in terms of improving generalization.
#
# In conclusion, the learning curve suggests that while the model benefits from additional training data, it may still be overfitting, particularly at the lower end of the training sample size. The model could potentially benefit from further regularization or more complex feature engineering to close the gap between the training and testing performance.

# %% [markdown]
# #### Evaluation Final Model with Extra Trees Algorithm

# %%
# Define final model with Extra Trees Regressor Algorithm for SF2 (After Tuning)
model_evl = ExtraTreesRegressor(
    n_estimators=350,
    max_depth=10,
    min_samples_split=4,
    min_samples_leaf=3,
    criterion='friedman_mse',
    random_state=42
)

# Define model with TransformedTargetRegressor
final_model_evl = TransformedTargetRegressor(model_evl, func=np.log, inverse_func=np.exp)

# %%
# Dict to save the final evaluation with Decision Tree Algoritm
results_final_evl = {
    'MAE': [],
    'MAPE': []
}

# Create pipeline final and Fit to X_train and y_train
pipe_final_evl = Pipeline(steps=[
    ('preprocessor', preprocessor_2),
    ('model', final_model_evl)
]).fit(X_train, y_train)

# Predict to X_val
y_pred_evl = pipe_final_evl.predict(X_val)

# Calculate RMSE, MAPE, Loss
results_final_evl['MAE'].append(mean_absolute_error(y_val, y_pred))
results_final_evl['MAPE'].append(mean_absolute_percentage_error(y_val, y_pred_evl))

# %%
# Show the Final Result of Final Model with Extra Trees Algoritm
pd.DataFrame(results_final_evl)
# Out:
#          MAE      MAPE
# 0  29.194483  0.170355

# %% [markdown]
# ### Insight on the Final Model Performance
#
# The final model, which is an Extra Trees Regressor tuned using the parameters from Set Feature 2, achieved the following evaluation metrics on the validation data:
# - **Mean Absolute Error (MAE):** 29.19
# - **Mean Absolute Percentage Error (MAPE):** 17.04%
#
# These results indicate that the model's predictions are, on average, about 29.19 units away from the actual values. The MAPE value suggests that the model's predictions deviate from the actual values by approximately 17.04% on average.
#
# Given the improvement in these metrics after tuning, the model demonstrates a strong ability to generalize and make accurate predictions on unseen data. However, while the MAE and MAPE values are reasonably low, there is still room for improvement, especially if further fine-tuning or feature engineering is applied.
#
# This model could serve as a solid baseline for deployment, or it could be further refined to enhance its predictive performance.

# %%
# Final Result with Extra Trees Algorith
residual_evl = pd.DataFrame(y_val).copy()
residual_evl['Predict'] = y_pred_evl
residual_evl['Residual'] = residual_evl['price'] - residual_evl['Predict']
residual_evl.head()
# Out:
#          price     Predict   Residual
# 258286  677.71  648.787404  28.922596
# 67221    57.26   55.843365   1.416635
# 205485   39.36   30.579132   8.780868
# 85948    89.81   91.633686  -1.823686
# 138264   89.69   70.736279  18.953721

# %%
# Residual Analysis with Extra Trees Algorithm
plt.figure(figsize=(10,6))
sns.scatterplot(data=residual_evl, x='Predict', y='Residual')
plt.title('Residual Analysis', fontweight='bold', loc='center', fontsize=16)
plt.show()

# %% [markdown]
# ### Residual Analysis
#
# The residual plot shows the difference between the actual and predicted values (residuals) plotted against the predicted values. In this analysis:
#
# - **Clustered Residuals:** There is a noticeable clustering of residuals around the 0-200 predicted value range. This suggests that the model performs well for lower predictions, as the residuals are close to zero, indicating low error.
#
# - **Increasing Variability:** As the predicted values increase, the spread of residuals becomes wider, indicating that the model's error increases with higher predicted values. This pattern suggests that the model may struggle to accurately predict higher values.
#
# - **Presence of Outliers:** There are several points with large positive or negative residuals, particularly for higher predicted values. These outliers suggest that the model is making significant errors in these cases, which could be due to the complexity of the data or potential overfitting in certain regions.
#
# Overall, while the model performs reasonably well for lower predicted values, it exhibits increased error and variability as predictions increase, highlighting areas where the model could be improved, perhaps by further tuning or incorporating additional features to better capture the variance in higher predictions.

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=residual_evl, x='Predict', y='price')
plt.title('Actual Vs Predict', fontweight='bold', loc='center', fontsize=16)
plt.show()

# %% [markdown]
# ### Actual vs. Predicted Plot
#
# The scatter plot comparing actual versus predicted values provides insights into the performance of the model:
#
# - **Positive Correlation:** There is a clear positive correlation between the actual and predicted values, indicating that the model generally captures the trend in the data. As the actual price increases, the predicted values also tend to increase, suggesting that the model is able to approximate the underlying relationship between the features and the target variable.
#
# - **Deviation from Perfect Prediction:** Ideally, all points would lie on a 45-degree diagonal line (where actual equals predicted). However, the points are dispersed around this line, with some noticeable deviations, especially for higher values. This suggests that while the model is generally accurate, it tends to overestimate or underestimate in certain ranges, particularly in higher price ranges.
#
# - **Concentration of Predictions:** There is a high concentration of points at the lower end of the price spectrum (0-200), where the model performs better, with predictions closely matching actual values. However, as prices increase, the predictions become more spread out, reflecting the model's increased difficulty in accurately predicting higher prices.
#
# Overall, the plot indicates that the model performs well for lower values but struggles with higher prices, leading to increased prediction error in those cases. Further refinement or feature engineering may be necessary to improve the model's accuracy for higher price predictions.

# %% [markdown]
# #### Learning Curve with Extra Trees Algorithm

# %%
# Set the required parameters
common_params = {
    "X": feature,
    "y": target,
    "train_sizes": np.linspace(0.1, 1.0, 10),
    "cv": 5,
    "score_type": "both",
    "n_jobs": 4,
    "line_kw": {"marker": "o"},
    "scoring": 'neg_mean_absolute_error',
}

# Generate learning curve plot
LearningCurveDisplay.from_estimator(pipe_final_evl, **common_params)

# show
plt.show()

# %% [markdown]
# ### Insight on Learning Curve
#
# The learning curve illustrates the performance of the model on both the training and testing datasets as the number of training samples increases:
#
# - **Training Metric:** The training score starts relatively high and decreases as the number of samples increases. This is typical behavior, as a model tends to fit the training data better when there are fewer samples. As more samples are added, the model's ability to memorize the training data decreases, leading to a lower training score. However, the training score stabilizes as the number of samples increases, indicating that the model has reached its capacity to learn from the training data.
#
# - **Testing Metric:** The testing score improves as the number of training samples increases, which indicates that the model is generalizing better with more data. The gap between the training and testing curves suggests that the model is learning and improving its performance on unseen data as it is trained with more samples.
#
# - **Gap Between Training and Testing Metrics:** The persistent gap between the training and testing metrics suggests that there may still be some overfitting, where the model performs better on the training data compared to the testing data. This gap does not close as more data is added, implying that the model might benefit from further regularization or different hyperparameter tuning.
#
# Overall, the learning curve suggests that while the model improves with more data, there is still room for improvement in its generalization capability, especially in reducing the gap between the training and testing scores.

# %% [markdown]
# <h4 style='text-align:left; color:darkcyan'><b> Finalized Model </b></h4>

# %%
# Fitting to Seen Data
# Split Seen Data to X_train_val and y_train_val
X_train_val = df_seen.drop(columns='price')
y_train_val = df_seen['price']

# %%
#Define Final Model
model_final_evl = DecisionTreeRegressor(
    criterion='friedman_mse',
    splitter='best',
    max_depth=12,
    min_samples_split=5,
    min_samples_leaf=10,
    random_state=42)

# Define model with TransformedTargetRegressor
model_final = TransformedTargetRegressor(model_final_evl, func=np.log, inverse_func=np.exp)


# Create pipeline final and Fit to X_train and y_train
final = Pipeline(steps=[
    ('preprocessor', preprocessor_2),
    ('model', model_final)
]).fit(X_train_val, y_train_val)

# %% [markdown]
# <h4 style='text-align:left; color:darkcyan'><b> Features Importance </b></h4>

# %%
# Get the transformer from the pipeline
preprocessor = final.named_steps['preprocessor']

# Initialize an empty list to store feature names
feature_names = []

# Process OneHotEncoder features
if 'onehot' in preprocessor.named_transformers_:
    onehot_feature_names = preprocessor.named_transformers_['onehot'].named_steps['onehot'].get_feature_names_out()
    feature_names.extend(onehot_feature_names)

# Process OrdinalEncoder features
if 'ordinal' in preprocessor.named_transformers_:
    ordinal_feature_names = preprocessor.named_transformers_['ordinal'].named_steps['ordinal'].get_feature_names_out()
    feature_names.extend(ordinal_feature_names)

# If there are features that are passed through unchanged (using 'passthrough')
if 'remainder' in preprocessor.named_transformers_ and preprocessor.named_transformers_['remainder'] == 'passthrough':
    # Assuming that these are columns that didn't undergo transformation
    remainder_feature_names = preprocessor.transformers[-1][-1]  # Get the original column names for passthrough
    feature_names.extend(remainder_feature_names)

# Get feature importances from the model
importances = final.named_steps['model'].regressor_.feature_importances_

# Handle cases where the lengths do not match
if len(feature_names) > len(importances):
    feature_names = feature_names[:len(importances)]
elif len(importances) > len(feature_names):
    importances = importances[:len(feature_names)]

# Create a DataFrame for feature importance
feature_importance = pd.DataFrame({
    'Features': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

# Display the DataFrame
feature_importance
# Out:
#           Features  Importance
# 15      x3_Economy    0.860811
# 17    arrival_time    0.062738
# 16  departure_time    0.038560
# 4       x0_Vistara    0.007655
# 0     x0_Air_India    0.007555
# 1      x0_GO_FIRST    0.003421
# 8       x1_Kolkata    0.002366
# 3      x0_SpiceJet    0.002303
# 13      x2_Kolkata    0.002189
# 2        x0_Indigo    0.002010
# 12    x2_Hyderabad    0.001342
# 10      x2_Chennai    0.001059
# 9        x1_Mumbai    0.001011
# 6         x1_Delhi    0.000858
# 18           stops    0.000808
# 11        x2_Delhi    0.000719
# 14       x2_Mumbai    0.000529
# 5       x1_Chennai    0.000499
# 7     x1_Hyderabad    0.000499

# %%
# Create Plot for Feature Importance
plt.figure(figsize=(10,8))
sns.barplot(data=feature_importance, x='Importance', y='Features')
plt.title('Features Importance', loc='left', fontweight='bold', fontsize=16)
plt.show()

# %% [markdown]
# ### Feature Importance:
#
# The feature importance plot reveals that the most significant feature influencing the model's predictions is `x3_Economy`, which stands out with a much higher importance score compared to all other features. This suggests that whether a flight is in the Economy class has the most substantial impact on the predicted outcome.
#
# The next most important features are `arrival_time` and `departure_time`, though their influence is considerably lower than `x3_Economy`. These features likely play a role in determining the overall price or outcome based on the timing of the flight.
#
# The remaining features, such as `x0_Vistara`, `x0_Air_India`, and various city-related features, contribute very little to the model's predictions, as indicated by their near-zero importance scores. This implies that while they might have some impact, it is not significant enough to be prioritized in the model.
#
# Overall, this analysis indicates that focusing on flight class (`x3_Economy`) and optimizing arrival and departure times could be key factors for better predictions or decisions based on this model.

# %% [markdown]
# <h4 style='text-align:left; color:darkcyan'><b> Model Confidence Level </b></h4>

# %%
test_df = df_unseen.copy()

# Definisikan class
test = SegmentPerformanceTest(
    feature_1='source_city', feature_2='departure_time', 
    alternative_scorer='neg_mean_absolute_error',
    max_segments=5, 
    max_cat_proportions=0.8
)
# Run test
test.run(estimator=final, data=test_df, target_label='price')

# %% [markdown]
# ### Insight on Negative Mean Absolute Error (MAE) by Source City and Departure Time:
#
# The heatmap above displays the negative mean absolute error (neg_MAE) across different source cities and departure times, providing insights into the model's performance for these combinations. A more negative value (closer to -50) indicates higher prediction errors, while values closer to 0 indicate lower errors.
#
# - **Mumbai and Early Morning Departures:** The model performs the worst with the highest error (-51.15) for flights departing early in the morning from Mumbai. This suggests that the model struggles to accurately predict outcomes for this specific scenario.
#
# - **Delhi and Early Morning Departures:** Another area of poor performance is with early morning departures from Delhi, with a neg_MAE of -43.13. This indicates that the model also faces challenges in predicting outcomes for early morning flights from Delhi.
#
# - **Bangalore and Evening Departures:** The model achieves its best performance for flights departing in the evening from Bangalore, with a neg_MAE of -24.60. This suggests that the model is relatively better at predicting outcomes for this scenario.
#
# - **General Trends:**
#   - **Early Morning Departures:** Across all cities, early morning departures generally have higher errors, indicating that the model is less accurate for flights leaving early in the morning.
#   - **Evening Departures:** Evening departures tend to have lower errors, especially for cities like Kolkata and Bangalore, suggesting better model performance during this time.
#
# - **Others Category:** The 'Others' category for both source cities and departure times generally shows higher errors, which may indicate less consistency or fewer data points for these combinations.
#
# Overall, the model's performance varies significantly depending on the time of departure and the source city, with the most challenging predictions occurring in the early morning from cities like Mumbai and Delhi. In contrast, the model performs better with evening departures, particularly from Bangalore.

# %%
test_df = df_unseen.copy()

# Definisikan class
test = SegmentPerformanceTest(
    feature_1='airline', feature_2='days_left', 
    alternative_scorer='neg_mean_absolute_error',
    max_segments=5, 
    max_cat_proportions=0.8
)
# Run test
test.run(estimator=final, data=test_df, target_label='price')

# %% [markdown]
# ### Insight on Negative Mean Absolute Error (MAE) by Airline and Days Left:
#
# The heatmap above illustrates the negative mean absolute error (neg_MAE) across different airlines and the number of days left until departure. The more negative values indicate higher prediction errors, while values closer to 0 indicate lower errors.
#
# - **Vistara:**
#   - Vistara has the highest prediction errors across all day ranges, particularly when there is only 1 to 12 days left until departure, with a neg_MAE of -61.32. This suggests that the model struggles significantly with Vistara flights, especially when the booking is made closer to the departure date.
#   - The error decreases slightly as the days left increase, but it remains higher than for other airlines, indicating a consistent challenge for the model in predicting Vistara flights accurately.
#
# - **Air India:**
#   - Air India also shows high prediction errors, especially when there are fewer days left before departure. The error is highest when there are 1 to 12 days left (-47.40) and decreases as the number of days left increases.
#   - However, even with 31 to 49 days left, the model struggles with Air India predictions, showing that the model finds it difficult to predict Air India flight prices accurately regardless of how far in advance the booking is made.
#
# - **Indigo:**
#   - Indigo shows much lower prediction errors across all day ranges. The model performs best with Indigo flights, with errors being the lowest when there are 22 to 31 days left (-10.88).
#   - This indicates that the model is more capable of predicting prices accurately for Indigo flights, especially when there are 12 to 49 days left before departure.
#
# - **Others Category:**
#   - The 'Others' category, which likely includes smaller or less frequent airlines, shows lower prediction errors, particularly when there are more than 12 days left until departure. This suggests that the model can predict prices more accurately for these flights, possibly due to more stable or predictable pricing patterns.
#
# - **General Trends:**
#   - Across all airlines, prediction errors are highest when there are fewer days left until departure, especially within 1 to 12 days. This suggests that the model finds it more challenging to predict flight prices accurately as the departure date approaches.
#   - The errors decrease as the number of days left increases, indicating that the model performs better with more time between booking and departure, allowing for more accurate price predictions.
#
# Overall, the model's performance varies significantly depending on the airline and how far in advance the booking is made, with the most challenging predictions occurring for Vistara and Air India flights booked closer to the departure date. Indigo and 'Others' airlines show lower errors, indicating better model performance in predicting their prices.

# %% [markdown]
# <h4 style='text-align:left; color:darkcyan'><b> How the Final Model Works </b></h4>

# %% [markdown]
# **The Final Model for this Customer Lifetime Value Prediction Case uses the Extra Trees Regressor Algorithm with the following parameters:**
#
# - **`n_estimators=400`**: The number of trees in the forest. This parameter controls the number of trees that are built in the model. A higher number of trees generally improves model performance but also increases training time.
#
# - **`criterion='squared_error'`**: The function to measure the quality of a split. The squared error is minimized, which is appropriate for regression tasks where the target variable is continuous.
#
# - **`max_depth=15`**: The maximum depth of the tree. This parameter prevents the trees from growing too deep and overfitting by controlling the maximum number of levels in each decision tree.
#
# - **`min_samples_split=4`**: The minimum number of samples required to split an internal node. This prevents the model from splitting nodes that are too small, which can lead to overfitting.
#
# - **`min_samples_leaf=3`**: The minimum number of samples required to be at a leaf node. This ensures that the leaves have enough samples to make reliable predictions.
#
# - **`max_features='auto'`**: The number of features to consider when looking for the best split. 'Auto' means that all features are considered.
#
# - **`random_state=42`**: Sets the seed for random number generation, ensuring that the results are reproducible.
#
# **Then, the Extra Trees Regressor Algorithm is defined as the variable `final_model_evl`, which is used within the TransformedTargetRegressor:**
#
# - **`TransformedTargetRegressor`**: Wraps the Extra Trees Regressor model with target transformation. The target variable is log-transformed using `np.log` before the model is trained, and predictions are returned to the original scale using `np.exp`. This is useful when the target distribution is skewed, as log transformation can help the model handle the target variable more effectively.
#
# **Pipeline**
#
# - **`Pipeline`**: Combines several data preprocessing and model training steps into a single object:
#   - **`'preprocessor'`**: This step includes data preprocessing such as normalization using `RobustScaler()`, encoding (Ordinal Encoding, OneHot Encoding), outlier detection, and imputation applied to the data before fitting the model.
#   - **`'model'`**: Applies the Extra Trees Regressor model wrapped by `TransformedTargetRegressor`.
#
# **Fitting the Data**
#
# - **`final.fit(X_train, y_train)`**: Trains the pipeline on the training data (X_train and y_train). The pipeline applies preprocessing to the data and then trains the Extra Trees Regressor with the processed data and the transformed target.
#
# **How the Extra Trees Regressor Model Works**
#
# - **Preprocessing**:
#
#   The data (X_train) is processed by the preprocessor, which may include normalization, encoding, or other feature transformations, ensuring that the data is in the optimal form for model training.
#
# - **Target Transformation**:
#
#   The target variable (y_train) is transformed using the log function (`np.log`) before training the Extra Trees Regressor model. This can improve model performance by addressing skewness in the target distribution. After training, the predictions are transformed back to the original scale using the exponential function (`np.exp`).
#
# - **Model Training**:
#
#   The Extra Trees Regressor is trained with the processed data (X_train) and the transformed target. The model constructs multiple trees, each built on different random subsets of the data and features, to create an ensemble that averages out predictions, reducing variance and improving model robustness.
#
# - **Prediction**:
#
#   After the model is trained, predictions can be made on new data. The predictions, initially in the transformed scale (log), are returned to the original scale using the exponential function (`np.exp`).
#
# - **Evaluation**:
#
#   The model is evaluated using regression metrics, such as Mean Absolute Error (MAE), on the test data to assess how well the model predicts the target variable.
#
# This pipeline ensures that the data is preprocessed consistently, the target variable is handled appropriately, and the model is trained and evaluated effectively.

# %% [markdown]
# <h4 style='text-align:left; color:darkcyan'><b> Interpretation of Final Model </b></h4>

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Extract the decision tree model
tree_model = final.named_steps['model'].regressor_

# Plot the decision tree
plt.figure(figsize=(20, 10))
plot_tree(tree_model, 
          feature_names=feature_names, 
          filled=True, 
          rounded=True,
          max_depth=1)
plt.show()

# %% [markdown]
# 1. **Root Node**:
#    - The root of the tree starts with the condition **x3_Economy <= 0.5**.
#    - If this condition is true (yes), the tree branches to the left; if false (no), it branches to the right.
#    - The **friedman_mse = 1.253** indicates the **Mean Squared Error (MSE)** at this node.
#    - **samples = 4802** shows the number of samples processed at this node.
#    - **value = 4.917** represents the average target value for the samples at this node.
#
# 2. **Left Branch (True Branch)**:
#    - On the left branch, the tree further splits based on **departure_time <= -0.721**.
#    - If this condition is true (yes), the tree further branches to the left; if false (no), it branches to the right.
#    - **friedman_mse = 0.079**, **samples = 1527**, and **value = 6.411** provide information similar to the root node but only for the subset of data that meets both conditions.
#
# 3. **Right Branch (False Branch)**:
#    - If **x3_Economy > 0.5**, the tree branches to the right, where the next condition is **arrival_time <= -0.457**.
#    - **friedman_mse = 0.274**, **samples = 3275**, and **value = 4.221** describe the data at this node.
#
# 4. **Leaf Nodes**:
#    - The nodes at the end of the branches (shown as gray boxes) are leaf nodes, which are the terminal nodes where no further splitting occurs, representing the final decision for the samples in that path.
#
# This tree visually represents the decision-making process of the model, where each split represents a feature-based decision point, and the leaf nodes represent the final predicted values.

# %% [markdown]
# <h4 style='text-align:left; color:darkcyan'><b> Limitation of Final Model </b></h4>

# %% [markdown]
# It's important to note that this model has limitations in predicting values effectively, particularly if deployed in scenarios where the input data exceeds the model's learned limits. If the model encounters data beyond these boundaries, the results may be less accurate. The limitations of the model are as follows:
# - Maximum flight duration: 49.83 hours
# - Maximum days left before flight: 49 days
# - Capable of predicting flight prices accurately within a maximum range of $123,071. Beyond this value, the predictions may be biased.

# %% [markdown]
# <h4 style='text-align:left; color:darkcyan'><b> Prediction on Unseen Data </b></h4>

# %%
predict_result = df_unseen.copy()
predict = final.predict(predict_result)
predict_result['Predict'] = predict
predict_result.head()
# Out:
#           airline  flight source_city departure_time stops arrival_time  \
# 102018  Air_India  AI-808   Bangalore          Night   one      Evening
# 274368    Vistara  UK-774     Kolkata          Night   one      Evening
# 99904    GO_FIRST  G8-805   Bangalore        Morning   one        Night
# 143506  Air_India  AI-424     Kolkata      Afternoon   one        Night
# 73165    GO_FIRST  G8-371      Mumbai        Evening   one        Night
#
#        destination_city     class  duration  days_left   price  price_binned  \
# 102018           Mumbai   Economy     21.25         45   78.94             5
# 274368          Chennai  Business     23.33         41  666.02            10
# 99904            Mumbai   Economy     15.25         34   57.68             3
# 143506        Hyderabad   Economy     34.08         11  134.10             7
# 73165         Hyderabad   Economy      7.00         22   42.89             1
#
#            Predict
# 102018   60.115373
# 274368  583.826761
# ...

# %% [markdown]
# The final model was applied to predict the flight prices on unseen data, and the following observations can be made:
#
# 1. **Predicted Prices Vary Significantly Across Different Flights**:
#    - The predicted prices show considerable variation depending on the flight and associated features. For instance, the predicted price for a flight from Bangalore to Mumbai with Air India is **$60.12**, while a flight from Kolkata to Chennai with Vistara is predicted at **$583.83**. This indicates that the model takes into account the different features like airline, departure time, duration, and days left before the flight to make nuanced predictions.
#
# 2. **Consistency with Actual Prices**:
#    - The predicted values are generally in the same range as the actual prices, although there may be slight deviations. For example, the actual price for the Vistara flight is $666.02, whereas the model predicts $583.83. This suggests that while the model is fairly accurate, there might be room for further fine-tuning to reduce discrepancies.
#
# 3. **Handling of Various Flight Classes and Durations**:
#    - The model effectively handles different flight classes and durations. For instance, the model predicts a lower price for the Economy class flight from Bangalore to Mumbai compared to the Business class flight from Kolkata to Chennai, which aligns with expectations.
#
# 4. **Potential for Use in Real-World Scenarios**:
#    - The model demonstrates strong predictive power, making it potentially valuable for real-world applications like pricing strategies, demand forecasting, and customer insights. However, the performance should continue to be validated with more unseen data to ensure robustness across different scenarios.
#
# These insights highlight the model's capability to generalize well to unseen data, capturing the complexities of the pricing patterns in the airline industry.

# %% [markdown]
# <h2 style='text-align:left; color:darkblue'><b> Conclusion & Recommendations </b></h1>

# %% [markdown]
# <h4 style='text-align:left; color:darkcyan'><b> Conclusion </b></h4>

# %% [markdown]
# From the experiments conducted, the following conclusions can be drawn:
#
# 1. **Influential Features on Flight Price**:
#     - **Economy Class** and **Arrival Time** are significant factors influencing **Flight Prices**.
#     - Other features such as **Departure Time** and specific airlines also play a role, but to a lesser extent.
#
# 2. **Machine Learning Model Performance**:
#     - **Model Metrics**:
#         - **Mean Absolute Error (MAE)**:
#             The MAE value of $29.19 indicates that the average absolute difference between the predicted and actual flight prices is around $29.19. This suggests that, on average, the model's predictions deviate by $29.19 from the actual prices.
#         - **Mean Absolute Percentage Error (MAPE)**:
#             The MAPE value of 15.22% shows that the average prediction error in percentage terms is around 15.22% of the actual prices. This reflects the relative error made by the model compared to the true values.
#
#     - **Model Performance**:
#         Overall, the Extra Trees Regressor model demonstrated strong predictive capabilities with the tuned parameters. The model's ability to generalize on unseen data is evident from the reduced errors, showing that it can effectively predict flight prices within a reasonable range. However, the residual analysis indicated some outliers, suggesting that further refinement could improve accuracy.
#
#     - **Model Interpretation**:
#         The decision-making process of the model indicates that **Economy Class** has the most substantial impact on predicting flight prices, followed by **Arrival Time** and **Departure Time**. The decision tree structure further reveals how these features interact to influence the final prediction.
#
# 3. **Impact on Travelers**:
#     - **Dynamic Pricing**:
#         The insights derived from this model can be leveraged to implement dynamic pricing strategies. Travelers could benefit from more personalized and competitive pricing based on their booking time, class preference, and travel patterns. For instance, early morning flights with fewer days left before departure could see price adjustments based on demand forecasts.
#     - **Travel Planning**:
#         Travelers can utilize the model's predictions to make informed decisions about the best times to book flights to get the best deals. Understanding how factors like days left before travel and departure time influence prices can help them optimize their travel costs.

# %% [markdown]
# <h4 style='text-align:left; color:darkcyan'><b> Recommendation </b></h4>

# %% [markdown]
# 1. **Modeling**:
#     - While the model performs well, the presence of outliers in the residual analysis suggests the need for further evaluation. Addressing these outliers can reduce the residuals and bring the predicted values closer to the actual prices, enhancing the model's accuracy.
#
# 2. **Business and Travelers**:
#     - **Business**:
#         Airlines can use this model to refine their pricing strategies, particularly by adjusting prices dynamically based on factors such as booking time and class preference. This approach can increase revenue while providing better deals for customers who book under specific conditions.
#     - **Travelers**:
#         Travelers should consider booking flights earlier, as the model indicates that prices tend to increase as the departure date approaches. Additionally, selecting flights during less popular times, such as late evening or early morning, may offer cost-saving opportunities.

# %% [markdown]
# <h4 style='text-align:left; color:darkcyan'><b> Saving Model </b></h4>

# %%
import os
import pickle

# Define the directory and filename
directory = '../Article_3 Irene/model/'
filename = 'final_model.sav'  # Ensure the filename is descriptive

# Create the directory if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)

# Save the model to disk
filepath = os.path.join(directory, filename)
pickle.dump(final, open(filepath, 'wb'))

print(f'Model saved to {filepath}')
# Out:
# Model saved to ../Article_3 Irene/model/final_model.sav
